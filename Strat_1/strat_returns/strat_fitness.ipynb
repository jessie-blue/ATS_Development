# %%
import os 
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt

# %%
ticker = 'XLU'
df = pd.read_csv(ticker + '.csv')
df['date'] = pd.to_datetime(df['date'])
df['year'] = df.date.dt.year

print('Yearly cumulative return: ',df.groupby(['year'])['ret'].sum())
df = df[df['date'] >= '2025-01-02']
# Out:
# Yearly cumulative return:  year
# 2005    0.306844
# 2006    0.081180
# 2007    0.585992
# 2008    0.735866
# 2009    1.101550
# 2010    0.812269
# 2011    0.803573
# 2012    0.777029
# 2013    0.464756
# 2014    0.089146
# 2015    0.725888
# 2016    0.052160
# 2017    0.264732
# 2018    0.575936
# 2019    0.447864
# 2020    0.047016
# 2021    0.210391
# 2022    0.417950
# 2023    0.336538
# 2024   -0.141030
# 2025    0.011027
# Name: ret, dtype: float64

# %%
hold = df[df['ret'] == 0]
wins = df[df['ret'] > 0]
loss = df[df['ret'] < 0]

print('Loss Days %: ' , (loss.shape[0] / df.shape[0])*100) 
print('Win Days %: ' , (wins.shape[0] / df.shape[0])*100)
print('Hold Days %: ' , round((hold.shape[0] / df.shape[0])*100,2))
# Out:
# Loss Days %:  28.57142857142857
# Win Days %:  71.42857142857143
# Hold Days %:  0.0

# %%
plt.figure(figsize=(10,7))
plt.hist(df['ret'], color = 'b')
# Out:
# (array([1., 0., 0., 1., 0., 0., 2., 1., 1., 1.]),
#  array([-0.00174429, -0.00127234, -0.00080039, -0.00032844,  0.0001435 ,
#          0.00061545,  0.0010874 ,  0.00155935,  0.00203129,  0.00250324,
#          0.00297519]),
#  <BarContainer object of 10 artists>)

# %%
plt.figure(figsize = (14,8) )
plt.plot(df.index, df.ret.cumsum(), color = 'b')
plt.title(f'Cumulative return for {ticker}')
plt.xlabel('Date')
plt.xticks(rotation = 'vertical')
plt.ylabel('Cumulative Return')
# Out:
# Text(0, 0.5, 'Cumulative Return')

# %%
df.groupby(['year'])['ret'].sum()
# Out:
# year
# 2025    0.032347
# Name: ret, dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 170 entries, 3169 to 3338
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    170 non-null    object
#  1   ret     170 non-null    float64
# dtypes: float64(1), object(1)
# memory usage: 4.0+ KB

# %%
df
# Out:
#            date       ret  year
# 4984 2025-01-03 -0.023520  2025
# 4985 2025-01-06  0.019220  2025
# 4986 2025-01-07  0.023458  2025
# 4987 2025-01-08  0.023876  2025
# 4988 2025-01-10  0.023876  2025
# 4989 2025-01-13 -0.069394  2025
