# %%
import os 
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt

# %%
ticker = 'SPY'
df = pd.read_csv(ticker + '.csv')
df['date'] = pd.to_datetime(df['date'])
df['year'] = df.date.dt.year

print('Yearly cumulative return: ',df.groupby(['year'])['ret'].sum())
df = df[df['date'] >= '2024-02-01']
# Out:
# Yearly cumulative return:  year
# 2005    0.063378
# 2006    0.141618
# 2007    0.326741
# 2008    0.926807
# 2009    0.287122
# 2010    0.425482
# 2011    0.408812
# 2012    0.436278
# 2013   -0.060391
# 2014    0.036856
# 2015    0.396162
# 2016    0.107251
# 2017   -0.024498
# 2018    0.706751
# 2019    0.147856
# 2020    0.576220
# 2021    0.221779
# 2022    0.620060
# 2023    0.185131
# 2024    0.321323
# 2025    0.091483
# Name: ret, dtype: float64

# %%
hold = df[df['ret'] == 0]
wins = df[df['ret'] > 0]
loss = df[df['ret'] < 0]

print('Loss Days %: ' , (loss.shape[0] / df.shape[0])*100) 
print('Win Days %: ' , (wins.shape[0] / df.shape[0])*100)
print('Hold Days %: ' , round((hold.shape[0] / df.shape[0])*100,2))
# Out:
# Loss Days %:  21.21212121212121
# Win Days %:  42.04545454545455
# Hold Days %:  36.74

# %%
plt.figure(figsize=(10,7))
plt.hist(df['ret'], color = 'b')
plt.xlabel('Return')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
plt.figure(figsize = (14,8) )
plt.plot(df.index, df.ret.cumsum(), color = 'b')
plt.title(f'Cumulative return for {ticker}')
plt.xlabel('Date')
plt.xticks(rotation = 'vertical')
plt.ylabel('Cumulative Return')
# Out:
# Text(0, 0.5, 'Cumulative Return')

# %%
df.groupby(['year'])['ret'].sum()
# Out:
# year
# 2024    0.289397
# 2025    0.091483
# Name: ret, dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 247 entries, 4764 to 5010
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    247 non-null    datetime64[ns]
#  1   ret     247 non-null    float64
#  2   year    247 non-null    int32
# dtypes: datetime64[ns](1), float64(1), int32(1)
# memory usage: 6.8 KB

# %%
df
# Out:
#            date       ret  year
# 4764 2024-02-01 -0.010682  2024
# 4765 2024-02-02  0.000000  2024
# 4766 2024-02-05  0.000000  2024
# 4767 2024-02-06 -0.007833  2024
# 4768 2024-02-07  0.000000  2024
# ...         ...       ...   ...
# 5006 2025-02-06 -0.006098  2025
# 5007 2025-02-07  0.014296  2025
# 5008 2025-02-10 -0.005599  2025
# 5009 2025-02-11 -0.007820  2025
# 5010 2025-02-12 -0.015579  2025
#
# [247 rows x 3 columns]
