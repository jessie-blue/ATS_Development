# %%
import os 
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt

# %%
ticker = 'XLI'
df = pd.read_csv(ticker + '.csv')
df['date'] = pd.to_datetime(df['date'])
df['year'] = df.date.dt.year

print('Yearly cumulative return: ',df.groupby(['year'])['ret'].sum())
df = df[df['date'] >= '2024-03-14']
# Out:
# Yearly cumulative return:  year
# 2005    0.012460
# 2006    0.069539
# 2007   -0.101583
# 2008    0.184358
# 2009    0.193504
# 2010    0.008094
# 2011    0.114709
# 2012    0.062594
# 2013   -0.043120
# 2014    0.058141
# 2015    0.049559
# 2016   -0.078292
# 2017   -0.074046
# 2018    0.186063
# 2019   -0.050205
# 2020    0.010983
# 2021   -0.043329
# 2022    0.114725
# 2023   -0.019368
# 2024    0.033398
# Name: ret, dtype: float64

# %%
hold = df[df['ret'] == 0]
wins = df[df['ret'] > 0]
loss = df[df['ret'] < 0]

print('Loss Days %: ' , (loss.shape[0] / df.shape[0])*100) 
print('Win Days %: ' , (wins.shape[0] / df.shape[0])*100)
print('Hold Days %: ' , round((hold.shape[0] / df.shape[0])*100,2))
# Out:
# Loss Days %:  37.01657458563536
# Win Days %:  48.61878453038674
# Hold Days %:  14.36

# %%
plt.figure(figsize=(10,7))
plt.hist(df['ret'], color = 'b')
# Out:
# (array([ 2., 12., 15., 69., 61., 18.,  0.,  3.,  0.,  1.]),
#  array([-0.0262162 , -0.01944319, -0.01267018, -0.00589717,  0.00087584,
#          0.00764885,  0.01442186,  0.02119487,  0.02796788,  0.03474089,
#          0.0415139 ]),
#  <BarContainer object of 10 artists>)

# %%
plt.figure(figsize = (14,8) )
plt.plot(df.index, df.ret.cumsum(), color = 'b')
plt.title(f'Cumulative return for {ticker}')
plt.xlabel('Date')
plt.xticks(rotation = 'vertical')
plt.ylabel('Cumulative Return')
# Out:
# Text(0, 0.5, 'Cumulative Return')

# %%
df.groupby(['year'])['ret'].sum()
# Out:
# year
# 2024   -0.043955
# Name: ret, dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 170 entries, 3169 to 3338
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    170 non-null    object
#  1   ret     170 non-null    float64
# dtypes: float64(1), object(1)
# memory usage: 4.0+ KB
