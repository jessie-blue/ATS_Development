# %% [markdown]
# #### TRY ALTERNATIVE SPECIFICATIONS AND EXPLORE IN MORE DETAIL LSTM MODEL BUILDING OPTIONS ####

# %%
import os 
from datetime import datetime


strat = 'Strat_1'
directory = os.getcwd().replace("\\", "/")
file_dir = directory
directory = directory.replace(strat, '')
parent_dir = directory
os.chdir(directory)
print(directory)

import yfinance as yf
import pandas as pd
import numpy as np
import torch
import torch.nn as nn

from pathlib import Path
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

import module_1.Preprocessing_functions as pf 
import module_1.techinical_analysis as tech 
import module_1.LSTM_Architecture as ls
# Out:
# c:/Users/User/Documents/ATS_Development/

# %%
ticker = 'SPY'

# Download SPY data from Yahoo Finance
def download_data(ticker, start, end):
    data = yf.download(ticker, start=start, end=end)
    return data

# Feature Engineering: Add momentum features
def add_features(df, model_1 = True):
    df = pf.create_momentum_feat(df, ticker)
    df = pf.technical_indicators(df).dropna()
    
    if model_1 == False:
        df = tech.reversal_patterns(df)
        df = tech.continuation_patterns(df)
        df = tech.magic_doji(df)
        
    return df
        

def compute_rsi(series, period):
    delta = series.diff(1)
    gain = (delta.where(delta > 0, 0)).rolling(window=period).mean()
    loss = (-delta.where(delta < 0, 0)).rolling(window=period).mean()
    rs = gain / loss
    rsi = 100 - (100 / (1 + rs))
    return rsi

# Prepare data for LSTM model
def prepare_data(data, sequence_length):
    #y = (data['Close'].shift(-1) > data['Close']).astype(int)  # 1 for green, 0 for red
    
    data['labels'] = (data['Open'].shift(-1) > data['Close']).astype(int) # 0 = False : 1 = True
    
    
    y = data.pop('labels')
    
    data = data.drop(columns = ["Open",
                                "High",
                                "Low",
                                "Close",
                                "Capital Gains", 
                                "Stock Splits"
                                ]).dropna()
    
    features = list(data.columns)
    scaler = StandardScaler()
    X_scaled = scaler.fit_transform(data[features])
    
    
     # Create sequences
    X, y_seq = [], []
    for i in range(len(X_scaled) - sequence_length):
        X.append(X_scaled[i:i + sequence_length])
        y_seq.append(y.iloc[i + sequence_length - 1])

    return np.array(X), np.array(y_seq)
    
    #y = y[:-1]  # Remove last value since it has no next day
    #X = X[:-1]  # Match X with y length
    #return X, y

# %%
class LSTMModel(nn.Module):
    def __init__(self, input_size, hidden_size, output_size, num_layers):
        super(LSTMModel, self).__init__()
        self.lstm = nn.LSTM(input_size, hidden_size, num_layers, batch_first=True)
        self.fc = nn.Linear(hidden_size, output_size)

    def forward(self, x):
        out, _ = self.lstm(x)
        out = self.fc(out[:, -1, :])
        return out

# %%
# Load and preprocess data
#data = download_data('SPY', start='2013-01-01', end='2024-01-01')
data = pf.downlaod_symbol_data(ticker, period = '130mo')

# Training parameters
INPUT_SIZE = data.shape[0]
HIDDEN_SIZE = 50
OUTPUT_SIZE = 2
NUM_LAYERS = 2
EPOCHS = int(1e3)
BATCH_SIZE = 32
LR = 0.001
SEQUENCE_LENGTH = 50

data = add_features(data)

### DEBUGGING data
X, y = prepare_data(data, SEQUENCE_LENGTH)

print('X shape: ', X.shape)
print('y shape: ', y.shape)
# Out:
# X shape:  (2438, 50, 23)
# y shape:  (2438,)

# %%
train_size_pct = 0.7

train_size = int(train_size_pct * X.shape[0])

X_train = X[ :train_size, :]
X_test = X[train_size :, :]

y_train = y[:train_size]
y_test = y[train_size:]

print('Training set shape', X_train.shape)
print('Test set shape', X_test.shape)
print('Training Labels shape', y_train.shape)
print('Test Labels shape', y_test.shape)
# Out:
# Training set shape (1706, 50, 23)
# Test set shape (732, 50, 23)
# Training Labels shape (1706,)
# Test Labels shape (732,)

# %%
print('Training set start date: ', data.iloc[ :train_size, :].index.min())
print('Training set end date: ', data.iloc[ :train_size, :].index.max())
print('Test set start date: ', data.iloc[train_size :, :].index.min())
print('Test set end date: ', data.iloc[train_size :, :].index.max())
# Out:
# Training set start date:  2015-02-23 00:00:00-05:00
# Training set end date:  2021-11-29 00:00:00-05:00
# Test set start date:  2021-11-30 00:00:00-05:00
# Test set end date:  2025-01-10 00:00:00-05:00

# %%
X_train = torch.tensor(X_train, dtype=torch.float32)
X_test = torch.tensor(X_test, dtype=torch.float32)
y_train = torch.tensor(y_train, dtype=torch.long)
y_test = torch.tensor(y_test, dtype=torch.long)

# %%
class CustomLSTMModel(nn.Module):
    def __init__(self, input_size, hidden_sizes, output_size):
        """
        Args:
            input_size (int): The number of input features.
            hidden_sizes (list): A list of hidden sizes for each LSTM layer (e.g., [128, 64, 32]).
            output_size (int): The number of output features.
        """
        super(CustomLSTMModel, self).__init__()
        self.hidden_sizes = hidden_sizes
        
        # Define the first LSTM layer
        self.lstm1 = nn.LSTM(input_size, hidden_sizes[0], batch_first=True)
        
        # Define subsequent LSTM layers
        self.lstm2 = nn.LSTM(hidden_sizes[0], hidden_sizes[1], batch_first=True)
        self.lstm3 = nn.LSTM(hidden_sizes[1], hidden_sizes[2], batch_first=True)
        
        # Fully connected layer for final output
        self.fc = nn.Linear(hidden_sizes[2], output_size)

    def forward(self, x):
        # Pass through the first LSTM layer
        out, _ = self.lstm1(x)
        
        # Pass through the second LSTM layer
        out, _ = self.lstm2(out)
        
        # Pass through the third LSTM layer
        out, _ = self.lstm3(out)
        
        # Pass the final output through the fully connected layer
        out = self.fc(out[:, -1, :])  # Use the last time-step's output
        return out

# %%
# Initialize model, loss, and optimizer
HIDDEN_SIZES = [128,64,32]
model = CustomLSTMModel(INPUT_SIZE, HIDDEN_SIZES, OUTPUT_SIZE)
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=LR)

# %% [markdown]
# print('outputs', outputs.shape)
# print('y_train', y_train.shape)
#
# train_predictions[3]

# %%
results = {}

best_epoch = 0
best_accuracy = 0 
best_model_name = ''

# Training loop
for epoch in range(EPOCHS):
    model.train()
    optimizer.zero_grad()
    outputs = model(X_train)
    loss = criterion(outputs, y_train)
    loss.backward()
    optimizer.step()

    # Evaluate on training set
    with torch.no_grad():
        train_predictions = outputs.argmax(dim=1)
        train_accuracy = accuracy_score(y_train, train_predictions)
        train_precision = precision_score(y_train, train_predictions, average='weighted', zero_division=0)
        train_recall = recall_score(y_train, train_predictions, average='weighted', zero_division=0)
        train_f1 = f1_score(y_train, train_predictions, average='weighted', zero_division=0)

    # Evaluate on validation set
    model.eval()
    with torch.no_grad():
        val_outputs = model(X_test)
        val_predictions = val_outputs.argmax(dim=1)
        val_accuracy = accuracy_score(y_test, val_predictions)
        val_precision = precision_score(y_test, val_predictions, average='weighted', zero_division=0)
        val_recall = recall_score(y_test, val_predictions, average='weighted', zero_division=0)
        val_f1 = f1_score(y_test, val_predictions, average='weighted', zero_division=0)

    
    if val_accuracy > best_accuracy: 
        
        best_accuracy = val_accuracy
        best_epoch = epoch
        
        DATE = datetime.today().strftime('%Y%m%d%H%M')
        MODEL_PATH = Path(file_dir + f"/lstm_models/{ticker}")
        MODEL_PATH.mkdir(parents = True, exist_ok = True)
        
        # CREATE MODEL SAVE PATH
        MODEL_NAME = f"LSTM_Class_Epoch_{epoch}_TestAcc_{val_accuracy:.2f}_TrainAcc_{train_accuracy:.2F}_{DATE}"
        MODEL_SAVE_PATH = MODEL_PATH / MODEL_NAME
        best_model_pathname = MODEL_SAVE_PATH
        # SAVE MODEL STATE DICT
        print(f"Saving model to: {MODEL_SAVE_PATH}")
        torch.save(obj = model.state_dict(), f = MODEL_SAVE_PATH)
        
        
    
    results[epoch]  = [(train_accuracy, val_accuracy)]
    print(f"Epoch [{epoch+1}/{EPOCHS}], Loss: {loss.item():.4f}, Train Accuracy: {train_accuracy:.4f}, Train Precision: {train_precision:.4f}, Train Recall: {train_recall:.4f}, Train F1: {train_f1:.4f}, Val Accuracy: {val_accuracy:.4f}, Val Precision: {val_precision:.4f}, Val Recall: {val_recall:.4f}, Val F1: {val_f1:.4f}")
# Out:
# Saving model to: c:\Users\User\Documents\ATS_Development\Strat_6\lstm_models\SPY\LSTM_Class_Epoch_0_TestAcc_0.53_TrainAcc_0.57_202501111825
# Epoch [1/2000], Loss: 0.6886, Train Accuracy: 0.5674, Train Precision: 0.3220, Train Recall: 0.5674, Train F1: 0.4108, Val Accuracy: 0.5301, Val Precision: 0.2810, Val Recall: 0.5301, Val F1: 0.3673
# Epoch [2/2000], Loss: 0.6869, Train Accuracy: 0.5674, Train Precision: 0.3220, Train Recall: 0.5674, Train F1: 0.4108, Val Accuracy: 0.5301, Val Precision: 0.2810, Val Recall: 0.5301, Val F1: 0.3673
# Epoch [3/2000], Loss: 0.6855, Train Accuracy: 0.5674, Train Precision: 0.3220, Train Recall: 0.5674, Train F1: 0.4108, Val Accuracy: 0.5301, Val Precision: 0.2810, Val Recall: 0.5301, Val F1: 0.3673
# Epoch [4/2000], Loss: 0.6844, Train Accuracy: 0.5674, Train Precision: 0.3220, Train Recall: 0.5674, Train F1: 0.4108, Val Accuracy: 0.5301, Val Precision: 0.2810, Val Recall: 0.5301, Val F1: 0.3673
# Epoch [5/2000], Loss: 0.6835, Train Accuracy: 0.5674, Train Precision: 0.3220, Train Recall: 0.5674, Train F1: 0.4108, Val Accuracy: 0.5301, Val Precision: 0.2810, Val Recall: 0.5301, Val F1: 0.3673
# Epoch [6/2000], Loss: 0.6829, Train Accuracy: 0.5674, Train Precision: 0.3220, Train Recall: 0.5674, Train F1: 0.4108, Val Accuracy: 0.5301, Val Precision: 0.2810, Val Recall: 0.5301, Val F1: 0.3673
# Epoch [7/2000], Loss: 0.6826, Train Accuracy: 0.5674, Train Precision: 0.3220, Train Recall: 0.5674, Train F1: 0.4108, Val Accuracy: 0.5301, Val Precision: 0.2810, Val Recall: 0.5301, Val F1: 0.3673
# Epoch [8/2000], Loss: 0.6825, Train Accuracy: 0.5674, Train Precision: 0.3220, Train Recall: 0.5674, Train F1: 0.4108, Val Accuracy: 0.5301, Val Precision: 0.2810, Val Recall: 0.5301, Val F1: 0.3673
# Epoch [9/2000], Loss: 0.6824, Train Accuracy: 0.5674, Train Precision: 0.3220, Train Recall: 0.5674, Train F1: 0.4108, Val Accuracy: 0.5301, Val Precision: 0.2810, Val Recall: 0.5301, Val F1: 0.3673
# Epoch [10/2000], Loss: 0.6822, Train Accuracy: 0.5674, Train Precision: 0.3220, Train Recall: 0.5674, Train F1: 0.4108, Val Accuracy: 0.5301, Val Precision: 0.2810, Val Recall: 0.5301, Val F1: 0.3673
# Epoch [11/2000], Loss: 0.6818, Train Accuracy: 0.5674, Train Precision: 0.3220, Train Recall: 0.5674, Train F1: 0.4108, Val Accuracy: 0.5301, Val Precision: 0.2810, Val Recall: 0.5301, Val F1: 0.3673
# Epoch [12/2000], Loss: 0.6814, Train Accuracy: 0.5674, Train Precision: 0.3220, Train Recall: 0.5674, Train F1: 0.4108, Val Accuracy: 0.5301, Val Precision: 0.2810, Val Recall: 0.5301, Val F1: 0.3673
# Epoch [13/2000], Loss: 0.6810, Train Accuracy: 0.5674, Train Precision: 0.3220, Train Recall: 0.5674, Train F1: 0.4108, Val Accuracy: 0.5301, Val Precision: 0.2810, Val Recall: 0.5301, Val F1: 0.3673
# Epoch [14/2000], Loss: 0.6806, Train Accuracy: 0.5674, Train Precision: 0.5383, Train Recall: 0.5674, Train F1: 0.4129, Val Accuracy: 0.5301, Val Precision: 0.5160, Val Recall: 0.5301, Val F1: 0.3697
# Saving model to: c:\Users\User\Documents\ATS_Development\Strat_6\lstm_models\SPY\LSTM_Class_Epoch_14_TestAcc_0.53_TrainAcc_0.57_202501111826
# Epoch [15/2000], Loss: 0.6804, Train Accuracy: 0.5698, Train Precision: 0.5705, Train Recall: 0.5698, Train F1: 0.4281, Val Accuracy: 0.5314, Val Precision: 0.5500, Val Recall: 0.5314, Val F1: 0.3774
# Epoch [16/2000], Loss: 0.6802, Train Accuracy: 0.5698, Train Precision: 0.5536, Train Recall: 0.5698, Train F1: 0.4454, Val Accuracy: 0.5314, Val Precision: 0.5305, Val Recall: 0.5314, Val F1: 0.3887
# Saving model to: c:\Users\User\Documents\ATS_Development\Strat_6\lstm_models\SPY\LSTM_Class_Epoch_16_TestAcc_0.54_TrainAcc_0.57_202501111826
# Epoch [17/2000], Loss: 0.6800, Train Accuracy: 0.5721, Train Precision: 0.5614, Train Recall: 0.5721, Train F1: 0.4575, Val Accuracy: 0.5355, Val Precision: 0.5571, Val Recall: 0.5355, Val F1: 0.4014
# Saving model to: c:\Users\User\Documents\ATS_Development\Strat_6\lstm_models\SPY\LSTM_Class_Epoch_17_TestAcc_0.54_TrainAcc_0.58_202501111826
# Epoch [18/2000], Loss: 0.6798, Train Accuracy: 0.5756, Train Precision: 0.5718, Train Recall: 0.5756, Train F1: 0.4689, Val Accuracy: 0.5369, Val Precision: 0.5619, Val Recall: 0.5369, Val F1: 0.4062
# Epoch [19/2000], Loss: 0.6795, Train Accuracy: 0.5744, Train Precision: 0.5649, Train Recall: 0.5744, Train F1: 0.4727, Val Accuracy: 0.5355, Val Precision: 0.5571, Val Recall: 0.5355, Val F1: 0.4014
# Epoch [20/2000], Loss: 0.6792, Train Accuracy: 0.5744, Train Precision: 0.5638, Train Recall: 0.5744, Train F1: 0.4755, Val Accuracy: 0.5342, Val Precision: 0.5482, Val Recall: 0.5342, Val F1: 0.3986
# Epoch [21/2000], Loss: 0.6787, Train Accuracy: 0.5750, Train Precision: 0.5655, Train Recall: 0.5750, Train F1: 0.4766, Val Accuracy: 0.5314, Val Precision: 0.5291, Val Recall: 0.5314, Val F1: 0.3908
# Epoch [22/2000], Loss: 0.6783, Train Accuracy: 0.5750, Train Precision: 0.5658, Train Recall: 0.5750, Train F1: 0.4759, Val Accuracy: 0.5328, Val Precision: 0.5505, Val Recall: 0.5328, Val F1: 0.3872
# Epoch [23/2000], Loss: 0.6778, Train Accuracy: 0.5733, Train Precision: 0.5615, Train Recall: 0.5733, Train F1: 0.4698, Val Accuracy: 0.5301, Val Precision: 0.5162, Val Recall: 0.5301, Val F1: 0.3813
# Epoch [24/2000], Loss: 0.6773, Train Accuracy: 0.5733, Train Precision: 0.5623, Train Recall: 0.5733, Train F1: 0.4675, Val Accuracy: 0.5273, Val Precision: 0.4684, Val Recall: 0.5273, Val F1: 0.3755
# Epoch [25/2000], Loss: 0.6768, Train Accuracy: 0.5768, Train Precision: 0.5787, Train Recall: 0.5768, Train F1: 0.4674, Val Accuracy: 0.5287, Val Precision: 0.4944, Val Recall: 0.5287, Val F1: 0.3784
# Epoch [26/2000], Loss: 0.6763, Train Accuracy: 0.5774, Train Precision: 0.5838, Train Recall: 0.5774, Train F1: 0.4654, Val Accuracy: 0.5287, Val Precision: 0.4944, Val Recall: 0.5287, Val F1: 0.3784
# Epoch [27/2000], Loss: 0.6757, Train Accuracy: 0.5774, Train Precision: 0.5807, Train Recall: 0.5774, Train F1: 0.4685, Val Accuracy: 0.5301, Val Precision: 0.5162, Val Recall: 0.5301, Val F1: 0.3836
# Epoch [28/2000], Loss: 0.6750, Train Accuracy: 0.5809, Train Precision: 0.5906, Train Recall: 0.5809, Train F1: 0.4767, Val Accuracy: 0.5260, Val Precision: 0.4737, Val Recall: 0.5260, Val F1: 0.3815
# Epoch [29/2000], Loss: 0.6743, Train Accuracy: 0.5832, Train Precision: 0.5891, Train Recall: 0.5832, Train F1: 0.4895, Val Accuracy: 0.5273, Val Precision: 0.4895, Val Recall: 0.5273, Val F1: 0.3844
# Epoch [30/2000], Loss: 0.6734, Train Accuracy: 0.5821, Train Precision: 0.5811, Train Recall: 0.5821, Train F1: 0.4946, Val Accuracy: 0.5314, Val Precision: 0.5280, Val Recall: 0.5314, Val F1: 0.3929
# Epoch [31/2000], Loss: 0.6725, Train Accuracy: 0.5803, Train Precision: 0.5731, Train Recall: 0.5803, Train F1: 0.5003, Val Accuracy: 0.5328, Val Precision: 0.5341, Val Recall: 0.5328, Val F1: 0.4019
# Epoch [32/2000], Loss: 0.6715, Train Accuracy: 0.5873, Train Precision: 0.5848, Train Recall: 0.5873, Train F1: 0.5172, Val Accuracy: 0.5314, Val Precision: 0.5232, Val Recall: 0.5314, Val F1: 0.4109
# Epoch [33/2000], Loss: 0.6705, Train Accuracy: 0.5891, Train Precision: 0.5822, Train Recall: 0.5891, Train F1: 0.5344, Val Accuracy: 0.5314, Val Precision: 0.5228, Val Recall: 0.5314, Val F1: 0.4147
# Epoch [34/2000], Loss: 0.6694, Train Accuracy: 0.5914, Train Precision: 0.5847, Train Recall: 0.5914, Train F1: 0.5415, Val Accuracy: 0.5314, Val Precision: 0.5220, Val Recall: 0.5314, Val F1: 0.4236
# Epoch [35/2000], Loss: 0.6683, Train Accuracy: 0.5932, Train Precision: 0.5855, Train Recall: 0.5932, Train F1: 0.5501, Val Accuracy: 0.5314, Val Precision: 0.5228, Val Recall: 0.5314, Val F1: 0.4147
# Epoch [36/2000], Loss: 0.6672, Train Accuracy: 0.5944, Train Precision: 0.5903, Train Recall: 0.5944, Train F1: 0.5424, Val Accuracy: 0.5328, Val Precision: 0.5264, Val Recall: 0.5328, Val F1: 0.4278
# Epoch [37/2000], Loss: 0.6660, Train Accuracy: 0.5973, Train Precision: 0.5929, Train Recall: 0.5973, Train F1: 0.5509, Val Accuracy: 0.5287, Val Precision: 0.5119, Val Recall: 0.5287, Val F1: 0.4167
# Epoch [38/2000], Loss: 0.6645, Train Accuracy: 0.5955, Train Precision: 0.5926, Train Recall: 0.5955, Train F1: 0.5428, Val Accuracy: 0.5314, Val Precision: 0.5228, Val Recall: 0.5314, Val F1: 0.4147
# Epoch [39/2000], Loss: 0.6638, Train Accuracy: 0.5955, Train Precision: 0.5973, Train Recall: 0.5955, Train F1: 0.5335, Val Accuracy: 0.5355, Val Precision: 0.5362, Val Recall: 0.5355, Val F1: 0.4295
# Epoch [40/2000], Loss: 0.6623, Train Accuracy: 0.5926, Train Precision: 0.5860, Train Recall: 0.5926, Train F1: 0.5445, Val Accuracy: 0.5369, Val Precision: 0.5399, Val Recall: 0.5369, Val F1: 0.4337
# Epoch [41/2000], Loss: 0.6608, Train Accuracy: 0.5944, Train Precision: 0.5882, Train Recall: 0.5944, Train F1: 0.5483, Val Accuracy: 0.5355, Val Precision: 0.5408, Val Recall: 0.5355, Val F1: 0.4189
# Saving model to: c:\Users\User\Documents\ATS_Development\Strat_6\lstm_models\SPY\LSTM_Class_Epoch_41_TestAcc_0.54_TrainAcc_0.60_202501111826
# Epoch [42/2000], Loss: 0.6596, Train Accuracy: 0.6020, Train Precision: 0.6014, Train Recall: 0.6020, Train F1: 0.5537, Val Accuracy: 0.5383, Val Precision: 0.5466, Val Recall: 0.5383, Val F1: 0.4311
# Saving model to: c:\Users\User\Documents\ATS_Development\Strat_6\lstm_models\SPY\LSTM_Class_Epoch_42_TestAcc_0.54_TrainAcc_0.60_202501111826
# Epoch [43/2000], Loss: 0.6576, Train Accuracy: 0.6043, Train Precision: 0.6002, Train Recall: 0.6043, Train F1: 0.5670, Val Accuracy: 0.5396, Val Precision: 0.5456, Val Recall: 0.5396, Val F1: 0.4435
# Epoch [44/2000], Loss: 0.6563, Train Accuracy: 0.6043, Train Precision: 0.5981, Train Recall: 0.6043, Train F1: 0.5733, Val Accuracy: 0.5355, Val Precision: 0.5419, Val Recall: 0.5355, Val F1: 0.4170
# Epoch [45/2000], Loss: 0.6541, Train Accuracy: 0.6096, Train Precision: 0.6089, Train Recall: 0.6096, Train F1: 0.5701, Val Accuracy: 0.5396, Val Precision: 0.5547, Val Recall: 0.5396, Val F1: 0.4285
# Epoch [46/2000], Loss: 0.6519, Train Accuracy: 0.6143, Train Precision: 0.6139, Train Recall: 0.6143, Train F1: 0.5784, Val Accuracy: 0.5383, Val Precision: 0.5440, Val Recall: 0.5383, Val F1: 0.4362
# Saving model to: c:\Users\User\Documents\ATS_Development\Strat_6\lstm_models\SPY\LSTM_Class_Epoch_46_TestAcc_0.54_TrainAcc_0.61_202501111826
# Epoch [47/2000], Loss: 0.6503, Train Accuracy: 0.6149, Train Precision: 0.6120, Train Recall: 0.6149, Train F1: 0.5847, Val Accuracy: 0.5437, Val Precision: 0.5719, Val Recall: 0.5437, Val F1: 0.4327
# Saving model to: c:\Users\User\Documents\ATS_Development\Strat_6\lstm_models\SPY\LSTM_Class_Epoch_47_TestAcc_0.55_TrainAcc_0.63_202501111826
# Epoch [48/2000], Loss: 0.6500, Train Accuracy: 0.6260, Train Precision: 0.6308, Train Recall: 0.6260, Train F1: 0.5906, Val Accuracy: 0.5451, Val Precision: 0.5491, Val Recall: 0.5451, Val F1: 0.4739
# Saving model to: c:\Users\User\Documents\ATS_Development\Strat_6\lstm_models\SPY\LSTM_Class_Epoch_48_TestAcc_0.55_TrainAcc_0.62_202501111826
# Epoch [49/2000], Loss: 0.6499, Train Accuracy: 0.6190, Train Precision: 0.6128, Train Recall: 0.6190, Train F1: 0.6038, Val Accuracy: 0.5478, Val Precision: 0.5547, Val Recall: 0.5478, Val F1: 0.4770
# Epoch [50/2000], Loss: 0.6448, Train Accuracy: 0.6196, Train Precision: 0.6143, Train Recall: 0.6196, Train F1: 0.6002, Val Accuracy: 0.5464, Val Precision: 0.5527, Val Recall: 0.5464, Val F1: 0.4736
# Epoch [51/2000], Loss: 0.6462, Train Accuracy: 0.6219, Train Precision: 0.6216, Train Recall: 0.6219, Train F1: 0.5917, Val Accuracy: 0.5464, Val Precision: 0.5487, Val Recall: 0.5464, Val F1: 0.4844
# Epoch [52/2000], Loss: 0.6416, Train Accuracy: 0.6266, Train Precision: 0.6247, Train Recall: 0.6266, Train F1: 0.6023, Val Accuracy: 0.5478, Val Precision: 0.5496, Val Recall: 0.5478, Val F1: 0.4909
# Saving model to: c:\Users\User\Documents\ATS_Development\Strat_6\lstm_models\SPY\LSTM_Class_Epoch_52_TestAcc_0.55_TrainAcc_0.62_202501111826
# Epoch [53/2000], Loss: 0.6415, Train Accuracy: 0.6225, Train Precision: 0.6165, Train Recall: 0.6225, Train F1: 0.6097, Val Accuracy: 0.5519, Val Precision: 0.5582, Val Recall: 0.5519, Val F1: 0.4917
# Epoch [54/2000], Loss: 0.6389, Train Accuracy: 0.6231, Train Precision: 0.6173, Train Recall: 0.6231, Train F1: 0.6092, Val Accuracy: 0.5437, Val Precision: 0.5435, Val Recall: 0.5437, Val F1: 0.4824
# Epoch [55/2000], Loss: 0.6373, Train Accuracy: 0.6348, Train Precision: 0.6336, Train Recall: 0.6348, Train F1: 0.6134, Val Accuracy: 0.5410, Val Precision: 0.5368, Val Recall: 0.5410, Val F1: 0.4910
# Epoch [56/2000], Loss: 0.6351, Train Accuracy: 0.6325, Train Precision: 0.6294, Train Recall: 0.6325, Train F1: 0.6139, Val Accuracy: 0.5314, Val Precision: 0.5225, Val Recall: 0.5314, Val F1: 0.4938
# Epoch [57/2000], Loss: 0.6331, Train Accuracy: 0.6301, Train Precision: 0.6248, Train Recall: 0.6301, Train F1: 0.6187, Val Accuracy: 0.5246, Val Precision: 0.5142, Val Recall: 0.5246, Val F1: 0.4932
# Epoch [58/2000], Loss: 0.6314, Train Accuracy: 0.6325, Train Precision: 0.6273, Train Recall: 0.6325, Train F1: 0.6235, Val Accuracy: 0.5342, Val Precision: 0.5263, Val Recall: 0.5342, Val F1: 0.4984
# Epoch [59/2000], Loss: 0.6285, Train Accuracy: 0.6389, Train Precision: 0.6353, Train Recall: 0.6389, Train F1: 0.6248, Val Accuracy: 0.5342, Val Precision: 0.5262, Val Recall: 0.5342, Val F1: 0.4924
# Epoch [60/2000], Loss: 0.6269, Train Accuracy: 0.6436, Train Precision: 0.6409, Train Recall: 0.6436, Train F1: 0.6289, Val Accuracy: 0.5369, Val Precision: 0.5300, Val Recall: 0.5369, Val F1: 0.5013
# Epoch [61/2000], Loss: 0.6241, Train Accuracy: 0.6413, Train Precision: 0.6367, Train Recall: 0.6413, Train F1: 0.6322, Val Accuracy: 0.5369, Val Precision: 0.5301, Val Recall: 0.5369, Val F1: 0.5074
# Epoch [62/2000], Loss: 0.6215, Train Accuracy: 0.6424, Train Precision: 0.6380, Train Recall: 0.6424, Train F1: 0.6339, Val Accuracy: 0.5383, Val Precision: 0.5318, Val Recall: 0.5383, Val F1: 0.5078
# Epoch [63/2000], Loss: 0.6195, Train Accuracy: 0.6460, Train Precision: 0.6427, Train Recall: 0.6460, Train F1: 0.6334, Val Accuracy: 0.5355, Val Precision: 0.5286, Val Recall: 0.5355, Val F1: 0.5097
# Epoch [64/2000], Loss: 0.6160, Train Accuracy: 0.6594, Train Precision: 0.6560, Train Recall: 0.6594, Train F1: 0.6524, Val Accuracy: 0.5314, Val Precision: 0.5239, Val Recall: 0.5314, Val F1: 0.5083
# Epoch [65/2000], Loss: 0.6138, Train Accuracy: 0.6501, Train Precision: 0.6461, Train Recall: 0.6501, Train F1: 0.6447, Val Accuracy: 0.5355, Val Precision: 0.5282, Val Recall: 0.5355, Val F1: 0.5026
# Epoch [66/2000], Loss: 0.6112, Train Accuracy: 0.6571, Train Precision: 0.6557, Train Recall: 0.6571, Train F1: 0.6439, Val Accuracy: 0.5287, Val Precision: 0.5207, Val Recall: 0.5287, Val F1: 0.5061
# Epoch [67/2000], Loss: 0.6081, Train Accuracy: 0.6594, Train Precision: 0.6560, Train Recall: 0.6594, Train F1: 0.6521, Val Accuracy: 0.5191, Val Precision: 0.5098, Val Recall: 0.5191, Val F1: 0.4982
# Epoch [68/2000], Loss: 0.6043, Train Accuracy: 0.6612, Train Precision: 0.6577, Train Recall: 0.6612, Train F1: 0.6550, Val Accuracy: 0.5232, Val Precision: 0.5144, Val Recall: 0.5232, Val F1: 0.5016
# Epoch [69/2000], Loss: 0.6035, Train Accuracy: 0.6700, Train Precision: 0.6685, Train Recall: 0.6700, Train F1: 0.6600, Val Accuracy: 0.5301, Val Precision: 0.5234, Val Recall: 0.5301, Val F1: 0.5145
# Epoch [70/2000], Loss: 0.6036, Train Accuracy: 0.6653, Train Precision: 0.6630, Train Recall: 0.6653, Train F1: 0.6634, Val Accuracy: 0.5273, Val Precision: 0.5189, Val Recall: 0.5273, Val F1: 0.5037
# Epoch [71/2000], Loss: 0.5993, Train Accuracy: 0.6747, Train Precision: 0.6758, Train Recall: 0.6747, Train F1: 0.6618, Val Accuracy: 0.5273, Val Precision: 0.5186, Val Recall: 0.5273, Val F1: 0.5018
# Epoch [72/2000], Loss: 0.5963, Train Accuracy: 0.6700, Train Precision: 0.6682, Train Recall: 0.6700, Train F1: 0.6606, Val Accuracy: 0.5246, Val Precision: 0.5156, Val Recall: 0.5246, Val F1: 0.5008
# Epoch [73/2000], Loss: 0.5924, Train Accuracy: 0.6712, Train Precision: 0.6690, Train Recall: 0.6712, Train F1: 0.6627, Val Accuracy: 0.5260, Val Precision: 0.5171, Val Recall: 0.5260, Val F1: 0.5013
# Epoch [74/2000], Loss: 0.5916, Train Accuracy: 0.6682, Train Precision: 0.6655, Train Recall: 0.6682, Train F1: 0.6606, Val Accuracy: 0.5287, Val Precision: 0.5213, Val Recall: 0.5287, Val F1: 0.5102
# Epoch [75/2000], Loss: 0.5875, Train Accuracy: 0.6694, Train Precision: 0.6664, Train Recall: 0.6694, Train F1: 0.6661, Val Accuracy: 0.5328, Val Precision: 0.5252, Val Recall: 0.5328, Val F1: 0.5069
# Epoch [76/2000], Loss: 0.5848, Train Accuracy: 0.6747, Train Precision: 0.6725, Train Recall: 0.6747, Train F1: 0.6670, Val Accuracy: 0.5260, Val Precision: 0.5173, Val Recall: 0.5260, Val F1: 0.5026
# Epoch [77/2000], Loss: 0.5818, Train Accuracy: 0.6788, Train Precision: 0.6776, Train Recall: 0.6788, Train F1: 0.6698, Val Accuracy: 0.5369, Val Precision: 0.5310, Val Recall: 0.5369, Val F1: 0.5208
# Epoch [78/2000], Loss: 0.5800, Train Accuracy: 0.6741, Train Precision: 0.6715, Train Recall: 0.6741, Train F1: 0.6715, Val Accuracy: 0.5205, Val Precision: 0.5100, Val Recall: 0.5205, Val F1: 0.4935
# Epoch [79/2000], Loss: 0.5791, Train Accuracy: 0.6800, Train Precision: 0.6779, Train Recall: 0.6800, Train F1: 0.6730, Val Accuracy: 0.5219, Val Precision: 0.5137, Val Recall: 0.5219, Val F1: 0.5039
# Epoch [80/2000], Loss: 0.5777, Train Accuracy: 0.6764, Train Precision: 0.6744, Train Recall: 0.6764, Train F1: 0.6748, Val Accuracy: 0.5219, Val Precision: 0.5119, Val Recall: 0.5219, Val F1: 0.4960
# Epoch [81/2000], Loss: 0.5744, Train Accuracy: 0.6811, Train Precision: 0.6813, Train Recall: 0.6811, Train F1: 0.6706, Val Accuracy: 0.5219, Val Precision: 0.5126, Val Recall: 0.5219, Val F1: 0.4992
# Epoch [82/2000], Loss: 0.5674, Train Accuracy: 0.6829, Train Precision: 0.6802, Train Recall: 0.6829, Train F1: 0.6790, Val Accuracy: 0.5260, Val Precision: 0.5181, Val Recall: 0.5260, Val F1: 0.5068
# Epoch [83/2000], Loss: 0.5669, Train Accuracy: 0.6876, Train Precision: 0.6860, Train Recall: 0.6876, Train F1: 0.6864, Val Accuracy: 0.5314, Val Precision: 0.5241, Val Recall: 0.5314, Val F1: 0.5102
# Epoch [84/2000], Loss: 0.5642, Train Accuracy: 0.6887, Train Precision: 0.6870, Train Recall: 0.6887, Train F1: 0.6824, Val Accuracy: 0.5260, Val Precision: 0.5200, Val Recall: 0.5260, Val F1: 0.5151
# Epoch [85/2000], Loss: 0.5608, Train Accuracy: 0.6870, Train Precision: 0.6847, Train Recall: 0.6870, Train F1: 0.6847, Val Accuracy: 0.5219, Val Precision: 0.5134, Val Recall: 0.5219, Val F1: 0.5028
# Epoch [86/2000], Loss: 0.5562, Train Accuracy: 0.6876, Train Precision: 0.6851, Train Recall: 0.6876, Train F1: 0.6839, Val Accuracy: 0.5314, Val Precision: 0.5242, Val Recall: 0.5314, Val F1: 0.5113
# Epoch [87/2000], Loss: 0.5546, Train Accuracy: 0.6829, Train Precision: 0.6805, Train Recall: 0.6829, Train F1: 0.6771, Val Accuracy: 0.5178, Val Precision: 0.5113, Val Recall: 0.5178, Val F1: 0.5072
# Epoch [88/2000], Loss: 0.5510, Train Accuracy: 0.6958, Train Precision: 0.6942, Train Recall: 0.6958, Train F1: 0.6945, Val Accuracy: 0.5219, Val Precision: 0.5133, Val Recall: 0.5219, Val F1: 0.5022
# Epoch [89/2000], Loss: 0.5481, Train Accuracy: 0.6905, Train Precision: 0.6889, Train Recall: 0.6905, Train F1: 0.6841, Val Accuracy: 0.5219, Val Precision: 0.5146, Val Recall: 0.5219, Val F1: 0.5075
# Epoch [90/2000], Loss: 0.5436, Train Accuracy: 0.6999, Train Precision: 0.6979, Train Recall: 0.6999, Train F1: 0.6978, Val Accuracy: 0.5150, Val Precision: 0.5066, Val Recall: 0.5150, Val F1: 0.4992
# Epoch [91/2000], Loss: 0.5401, Train Accuracy: 0.6964, Train Precision: 0.6941, Train Recall: 0.6964, Train F1: 0.6931, Val Accuracy: 0.5123, Val Precision: 0.5034, Val Recall: 0.5123, Val F1: 0.4959
# Epoch [92/2000], Loss: 0.5367, Train Accuracy: 0.7081, Train Precision: 0.7062, Train Recall: 0.7081, Train F1: 0.7047, Val Accuracy: 0.5150, Val Precision: 0.5077, Val Recall: 0.5150, Val F1: 0.5026
# Epoch [93/2000], Loss: 0.5322, Train Accuracy: 0.7128, Train Precision: 0.7110, Train Recall: 0.7128, Train F1: 0.7109, Val Accuracy: 0.5150, Val Precision: 0.5063, Val Recall: 0.5150, Val F1: 0.4982
# Epoch [94/2000], Loss: 0.5303, Train Accuracy: 0.7069, Train Precision: 0.7052, Train Recall: 0.7069, Train F1: 0.7027, Val Accuracy: 0.5109, Val Precision: 0.5073, Val Recall: 0.5109, Val F1: 0.5071
# Epoch [95/2000], Loss: 0.5368, Train Accuracy: 0.7087, Train Precision: 0.7099, Train Recall: 0.7087, Train F1: 0.7092, Val Accuracy: 0.5246, Val Precision: 0.5135, Val Recall: 0.5246, Val F1: 0.4885
# Epoch [96/2000], Loss: 0.5640, Train Accuracy: 0.6829, Train Precision: 0.6930, Train Recall: 0.6829, Train F1: 0.6636, Val Accuracy: 0.5164, Val Precision: 0.5132, Val Recall: 0.5164, Val F1: 0.5131
# Epoch [97/2000], Loss: 0.5576, Train Accuracy: 0.6923, Train Precision: 0.7054, Train Recall: 0.6923, Train F1: 0.6935, Val Accuracy: 0.5109, Val Precision: 0.5100, Val Recall: 0.5109, Val F1: 0.5103
# Epoch [98/2000], Loss: 0.5447, Train Accuracy: 0.7098, Train Precision: 0.7114, Train Recall: 0.7098, Train F1: 0.7104, Val Accuracy: 0.5205, Val Precision: 0.5137, Val Recall: 0.5205, Val F1: 0.5082
# Epoch [99/2000], Loss: 0.5337, Train Accuracy: 0.7052, Train Precision: 0.7049, Train Recall: 0.7052, Train F1: 0.6984, Val Accuracy: 0.5150, Val Precision: 0.5018, Val Recall: 0.5150, Val F1: 0.4826
# Epoch [100/2000], Loss: 0.5394, Train Accuracy: 0.6975, Train Precision: 0.7065, Train Recall: 0.6975, Train F1: 0.6820, Val Accuracy: 0.5164, Val Precision: 0.5039, Val Recall: 0.5164, Val F1: 0.4852
# Epoch [101/2000], Loss: 0.5276, Train Accuracy: 0.7128, Train Precision: 0.7135, Train Recall: 0.7128, Train F1: 0.7058, Val Accuracy: 0.5191, Val Precision: 0.5124, Val Recall: 0.5191, Val F1: 0.5075
# Epoch [102/2000], Loss: 0.5252, Train Accuracy: 0.7181, Train Precision: 0.7183, Train Recall: 0.7181, Train F1: 0.7182, Val Accuracy: 0.5205, Val Precision: 0.5164, Val Recall: 0.5205, Val F1: 0.5155
# Epoch [103/2000], Loss: 0.5286, Train Accuracy: 0.7245, Train Precision: 0.7311, Train Recall: 0.7245, Train F1: 0.7257, Val Accuracy: 0.5191, Val Precision: 0.5145, Val Recall: 0.5191, Val F1: 0.5131
# Epoch [104/2000], Loss: 0.5168, Train Accuracy: 0.7216, Train Precision: 0.7218, Train Recall: 0.7216, Train F1: 0.7217, Val Accuracy: 0.5301, Val Precision: 0.5234, Val Recall: 0.5301, Val F1: 0.5145
# Epoch [105/2000], Loss: 0.5145, Train Accuracy: 0.7192, Train Precision: 0.7180, Train Recall: 0.7192, Train F1: 0.7153, Val Accuracy: 0.5328, Val Precision: 0.5257, Val Recall: 0.5328, Val F1: 0.5113
# Epoch [106/2000], Loss: 0.5167, Train Accuracy: 0.7210, Train Precision: 0.7214, Train Recall: 0.7210, Train F1: 0.7150, Val Accuracy: 0.5191, Val Precision: 0.5110, Val Recall: 0.5191, Val F1: 0.5027
# Epoch [107/2000], Loss: 0.5067, Train Accuracy: 0.7286, Train Precision: 0.7274, Train Recall: 0.7286, Train F1: 0.7255, Val Accuracy: 0.5191, Val Precision: 0.5134, Val Recall: 0.5191, Val F1: 0.5103
# Epoch [108/2000], Loss: 0.5055, Train Accuracy: 0.7327, Train Precision: 0.7326, Train Recall: 0.7327, Train F1: 0.7327, Val Accuracy: 0.5205, Val Precision: 0.5145, Val Recall: 0.5205, Val F1: 0.5108
# Epoch [109/2000], Loss: 0.5029, Train Accuracy: 0.7351, Train Precision: 0.7370, Train Recall: 0.7351, Train F1: 0.7357, Val Accuracy: 0.5219, Val Precision: 0.5137, Val Recall: 0.5219, Val F1: 0.5039
# Epoch [110/2000], Loss: 0.4971, Train Accuracy: 0.7309, Train Precision: 0.7297, Train Recall: 0.7309, Train F1: 0.7299, Val Accuracy: 0.5178, Val Precision: 0.5078, Val Recall: 0.5178, Val F1: 0.4953
# Epoch [111/2000], Loss: 0.4959, Train Accuracy: 0.7268, Train Precision: 0.7261, Train Recall: 0.7268, Train F1: 0.7227, Val Accuracy: 0.5191, Val Precision: 0.5113, Val Recall: 0.5191, Val F1: 0.5037
# Epoch [112/2000], Loss: 0.4916, Train Accuracy: 0.7333, Train Precision: 0.7322, Train Recall: 0.7333, Train F1: 0.7301, Val Accuracy: 0.5164, Val Precision: 0.5102, Val Recall: 0.5164, Val F1: 0.5068
# Epoch [113/2000], Loss: 0.4875, Train Accuracy: 0.7392, Train Precision: 0.7380, Train Recall: 0.7392, Train F1: 0.7382, Val Accuracy: 0.5205, Val Precision: 0.5137, Val Recall: 0.5205, Val F1: 0.5082
# Epoch [114/2000], Loss: 0.4838, Train Accuracy: 0.7456, Train Precision: 0.7448, Train Recall: 0.7456, Train F1: 0.7451, Val Accuracy: 0.5123, Val Precision: 0.5023, Val Recall: 0.5123, Val F1: 0.4926
# Epoch [115/2000], Loss: 0.4815, Train Accuracy: 0.7444, Train Precision: 0.7432, Train Recall: 0.7444, Train F1: 0.7429, Val Accuracy: 0.5137, Val Precision: 0.5043, Val Recall: 0.5137, Val F1: 0.4954
# Epoch [116/2000], Loss: 0.4758, Train Accuracy: 0.7485, Train Precision: 0.7473, Train Recall: 0.7485, Train F1: 0.7470, Val Accuracy: 0.5164, Val Precision: 0.5096, Val Recall: 0.5164, Val F1: 0.5051
# Epoch [117/2000], Loss: 0.4741, Train Accuracy: 0.7491, Train Precision: 0.7486, Train Recall: 0.7491, Train F1: 0.7488, Val Accuracy: 0.5205, Val Precision: 0.5131, Val Recall: 0.5205, Val F1: 0.5064
# Epoch [118/2000], Loss: 0.4684, Train Accuracy: 0.7497, Train Precision: 0.7494, Train Recall: 0.7497, Train F1: 0.7495, Val Accuracy: 0.5082, Val Precision: 0.4968, Val Recall: 0.5082, Val F1: 0.4862
# Epoch [119/2000], Loss: 0.4671, Train Accuracy: 0.7567, Train Precision: 0.7561, Train Recall: 0.7567, Train F1: 0.7563, Val Accuracy: 0.5205, Val Precision: 0.5125, Val Recall: 0.5205, Val F1: 0.5038
# Epoch [120/2000], Loss: 0.4613, Train Accuracy: 0.7626, Train Precision: 0.7628, Train Recall: 0.7626, Train F1: 0.7627, Val Accuracy: 0.5232, Val Precision: 0.5167, Val Recall: 0.5232, Val F1: 0.5110
# Epoch [121/2000], Loss: 0.4589, Train Accuracy: 0.7626, Train Precision: 0.7623, Train Recall: 0.7626, Train F1: 0.7624, Val Accuracy: 0.5219, Val Precision: 0.5138, Val Recall: 0.5219, Val F1: 0.5045
# Epoch [122/2000], Loss: 0.4541, Train Accuracy: 0.7556, Train Precision: 0.7545, Train Recall: 0.7556, Train F1: 0.7546, Val Accuracy: 0.5314, Val Precision: 0.5249, Val Recall: 0.5314, Val F1: 0.5157
# Epoch [123/2000], Loss: 0.4501, Train Accuracy: 0.7732, Train Precision: 0.7735, Train Recall: 0.7732, Train F1: 0.7733, Val Accuracy: 0.5314, Val Precision: 0.5254, Val Recall: 0.5314, Val F1: 0.5181
# Epoch [124/2000], Loss: 0.4464, Train Accuracy: 0.7749, Train Precision: 0.7765, Train Recall: 0.7749, Train F1: 0.7754, Val Accuracy: 0.5150, Val Precision: 0.5052, Val Recall: 0.5150, Val F1: 0.4948
# Epoch [125/2000], Loss: 0.4435, Train Accuracy: 0.7691, Train Precision: 0.7681, Train Recall: 0.7691, Train F1: 0.7678, Val Accuracy: 0.5396, Val Precision: 0.5347, Val Recall: 0.5396, Val F1: 0.5283
# Epoch [126/2000], Loss: 0.4392, Train Accuracy: 0.7796, Train Precision: 0.7806, Train Recall: 0.7796, Train F1: 0.7800, Val Accuracy: 0.5287, Val Precision: 0.5217, Val Recall: 0.5287, Val F1: 0.5123
# Epoch [127/2000], Loss: 0.4342, Train Accuracy: 0.7790, Train Precision: 0.7786, Train Recall: 0.7790, Train F1: 0.7787, Val Accuracy: 0.5301, Val Precision: 0.5237, Val Recall: 0.5301, Val F1: 0.5160
# Epoch [128/2000], Loss: 0.4301, Train Accuracy: 0.7925, Train Precision: 0.7925, Train Recall: 0.7925, Train F1: 0.7925, Val Accuracy: 0.5205, Val Precision: 0.5130, Val Recall: 0.5205, Val F1: 0.5059
# Epoch [129/2000], Loss: 0.4251, Train Accuracy: 0.7925, Train Precision: 0.7931, Train Recall: 0.7925, Train F1: 0.7927, Val Accuracy: 0.5273, Val Precision: 0.5206, Val Recall: 0.5273, Val F1: 0.5127
# Epoch [130/2000], Loss: 0.4216, Train Accuracy: 0.7948, Train Precision: 0.7959, Train Recall: 0.7948, Train F1: 0.7952, Val Accuracy: 0.5232, Val Precision: 0.5162, Val Recall: 0.5232, Val F1: 0.5092
# Epoch [131/2000], Loss: 0.4171, Train Accuracy: 0.8036, Train Precision: 0.8040, Train Recall: 0.8036, Train F1: 0.8038, Val Accuracy: 0.5096, Val Precision: 0.4997, Val Recall: 0.5096, Val F1: 0.4914
# Epoch [132/2000], Loss: 0.4143, Train Accuracy: 0.7995, Train Precision: 0.7991, Train Recall: 0.7995, Train F1: 0.7993, Val Accuracy: 0.5287, Val Precision: 0.5242, Val Recall: 0.5287, Val F1: 0.5220
# Epoch [133/2000], Loss: 0.4308, Train Accuracy: 0.7913, Train Precision: 0.7982, Train Recall: 0.7913, Train F1: 0.7923, Val Accuracy: 0.5178, Val Precision: 0.5057, Val Recall: 0.5178, Val F1: 0.4870
# Epoch [134/2000], Loss: 0.4984, Train Accuracy: 0.7438, Train Precision: 0.7529, Train Recall: 0.7438, Train F1: 0.7343, Val Accuracy: 0.5232, Val Precision: 0.5216, Val Recall: 0.5232, Val F1: 0.5220
# Epoch [135/2000], Loss: 0.4788, Train Accuracy: 0.7544, Train Precision: 0.7781, Train Recall: 0.7544, Train F1: 0.7548, Val Accuracy: 0.5273, Val Precision: 0.5260, Val Recall: 0.5273, Val F1: 0.5263
# Epoch [136/2000], Loss: 0.4578, Train Accuracy: 0.7749, Train Precision: 0.7796, Train Recall: 0.7749, Train F1: 0.7758, Val Accuracy: 0.5246, Val Precision: 0.5182, Val Recall: 0.5246, Val F1: 0.5127
# Epoch [137/2000], Loss: 0.4451, Train Accuracy: 0.7685, Train Precision: 0.7706, Train Recall: 0.7685, Train F1: 0.7643, Val Accuracy: 0.5396, Val Precision: 0.5338, Val Recall: 0.5396, Val F1: 0.5199
# Epoch [138/2000], Loss: 0.4385, Train Accuracy: 0.7819, Train Precision: 0.7844, Train Recall: 0.7819, Train F1: 0.7782, Val Accuracy: 0.5314, Val Precision: 0.5250, Val Recall: 0.5314, Val F1: 0.5162
# Epoch [139/2000], Loss: 0.4350, Train Accuracy: 0.7837, Train Precision: 0.7834, Train Recall: 0.7837, Train F1: 0.7835, Val Accuracy: 0.5205, Val Precision: 0.5155, Val Recall: 0.5205, Val F1: 0.5133
# Epoch [140/2000], Loss: 0.4280, Train Accuracy: 0.7866, Train Precision: 0.7942, Train Recall: 0.7866, Train F1: 0.7876, Val Accuracy: 0.5150, Val Precision: 0.5119, Val Recall: 0.5150, Val F1: 0.5118
# Epoch [141/2000], Loss: 0.4262, Train Accuracy: 0.7819, Train Precision: 0.7886, Train Recall: 0.7819, Train F1: 0.7829, Val Accuracy: 0.5150, Val Precision: 0.5103, Val Recall: 0.5150, Val F1: 0.5091
# Epoch [142/2000], Loss: 0.4178, Train Accuracy: 0.7960, Train Precision: 0.7971, Train Recall: 0.7960, Train F1: 0.7964, Val Accuracy: 0.5246, Val Precision: 0.5187, Val Recall: 0.5246, Val F1: 0.5143
# Epoch [143/2000], Loss: 0.4124, Train Accuracy: 0.7931, Train Precision: 0.7929, Train Recall: 0.7931, Train F1: 0.7930, Val Accuracy: 0.5232, Val Precision: 0.5163, Val Recall: 0.5232, Val F1: 0.5097
# Epoch [144/2000], Loss: 0.4119, Train Accuracy: 0.7937, Train Precision: 0.7930, Train Recall: 0.7937, Train F1: 0.7931, Val Accuracy: 0.5178, Val Precision: 0.5103, Val Recall: 0.5178, Val F1: 0.5040
# Epoch [145/2000], Loss: 0.4021, Train Accuracy: 0.8036, Train Precision: 0.8033, Train Recall: 0.8036, Train F1: 0.8034, Val Accuracy: 0.5219, Val Precision: 0.5162, Val Recall: 0.5219, Val F1: 0.5127
# Epoch [146/2000], Loss: 0.3987, Train Accuracy: 0.8072, Train Precision: 0.8070, Train Recall: 0.8072, Train F1: 0.8071, Val Accuracy: 0.5205, Val Precision: 0.5159, Val Recall: 0.5205, Val F1: 0.5143
# Epoch [147/2000], Loss: 0.3999, Train Accuracy: 0.8042, Train Precision: 0.8048, Train Recall: 0.8042, Train F1: 0.8045, Val Accuracy: 0.5205, Val Precision: 0.5153, Val Recall: 0.5205, Val F1: 0.5130
# Epoch [148/2000], Loss: 0.3887, Train Accuracy: 0.8095, Train Precision: 0.8111, Train Recall: 0.8095, Train F1: 0.8099, Val Accuracy: 0.5164, Val Precision: 0.5099, Val Recall: 0.5164, Val F1: 0.5060
# Epoch [149/2000], Loss: 0.3875, Train Accuracy: 0.8060, Train Precision: 0.8072, Train Recall: 0.8060, Train F1: 0.8064, Val Accuracy: 0.5232, Val Precision: 0.5167, Val Recall: 0.5232, Val F1: 0.5110
# Epoch [150/2000], Loss: 0.3846, Train Accuracy: 0.8036, Train Precision: 0.8040, Train Recall: 0.8036, Train F1: 0.8038, Val Accuracy: 0.5096, Val Precision: 0.5023, Val Recall: 0.5096, Val F1: 0.4984
# Epoch [151/2000], Loss: 0.3775, Train Accuracy: 0.8171, Train Precision: 0.8169, Train Recall: 0.8171, Train F1: 0.8170, Val Accuracy: 0.5096, Val Precision: 0.5028, Val Recall: 0.5096, Val F1: 0.4996
# Epoch [152/2000], Loss: 0.3733, Train Accuracy: 0.8277, Train Precision: 0.8279, Train Recall: 0.8277, Train F1: 0.8278, Val Accuracy: 0.5164, Val Precision: 0.5104, Val Recall: 0.5164, Val F1: 0.5072
# Epoch [153/2000], Loss: 0.3718, Train Accuracy: 0.8230, Train Precision: 0.8247, Train Recall: 0.8230, Train F1: 0.8234, Val Accuracy: 0.5137, Val Precision: 0.5071, Val Recall: 0.5137, Val F1: 0.5036
# Epoch [154/2000], Loss: 0.3673, Train Accuracy: 0.8218, Train Precision: 0.8230, Train Recall: 0.8218, Train F1: 0.8222, Val Accuracy: 0.5178, Val Precision: 0.5106, Val Recall: 0.5178, Val F1: 0.5050
# Epoch [155/2000], Loss: 0.3618, Train Accuracy: 0.8247, Train Precision: 0.8244, Train Recall: 0.8247, Train F1: 0.8245, Val Accuracy: 0.5191, Val Precision: 0.5118, Val Recall: 0.5191, Val F1: 0.5057
# Epoch [156/2000], Loss: 0.3594, Train Accuracy: 0.8271, Train Precision: 0.8267, Train Recall: 0.8271, Train F1: 0.8267, Val Accuracy: 0.5178, Val Precision: 0.5114, Val Recall: 0.5178, Val F1: 0.5076
# Epoch [157/2000], Loss: 0.3543, Train Accuracy: 0.8300, Train Precision: 0.8304, Train Recall: 0.8300, Train F1: 0.8302, Val Accuracy: 0.5178, Val Precision: 0.5122, Val Recall: 0.5178, Val F1: 0.5095
# Epoch [158/2000], Loss: 0.3511, Train Accuracy: 0.8335, Train Precision: 0.8352, Train Recall: 0.8335, Train F1: 0.8340, Val Accuracy: 0.5205, Val Precision: 0.5145, Val Recall: 0.5205, Val F1: 0.5108
# Epoch [159/2000], Loss: 0.3476, Train Accuracy: 0.8347, Train Precision: 0.8355, Train Recall: 0.8347, Train F1: 0.8350, Val Accuracy: 0.5150, Val Precision: 0.5080, Val Recall: 0.5150, Val F1: 0.5035
# Epoch [160/2000], Loss: 0.3424, Train Accuracy: 0.8411, Train Precision: 0.8414, Train Recall: 0.8411, Train F1: 0.8412, Val Accuracy: 0.5137, Val Precision: 0.5071, Val Recall: 0.5137, Val F1: 0.5036
# Epoch [161/2000], Loss: 0.3397, Train Accuracy: 0.8406, Train Precision: 0.8414, Train Recall: 0.8406, Train F1: 0.8408, Val Accuracy: 0.5150, Val Precision: 0.5087, Val Recall: 0.5150, Val F1: 0.5052
# Epoch [162/2000], Loss: 0.3347, Train Accuracy: 0.8458, Train Precision: 0.8464, Train Recall: 0.8458, Train F1: 0.8460, Val Accuracy: 0.5109, Val Precision: 0.5045, Val Recall: 0.5109, Val F1: 0.5016
# Epoch [163/2000], Loss: 0.3317, Train Accuracy: 0.8470, Train Precision: 0.8471, Train Recall: 0.8470, Train F1: 0.8470, Val Accuracy: 0.5150, Val Precision: 0.5096, Val Recall: 0.5150, Val F1: 0.5075
# Epoch [164/2000], Loss: 0.3273, Train Accuracy: 0.8558, Train Precision: 0.8570, Train Recall: 0.8558, Train F1: 0.8561, Val Accuracy: 0.5164, Val Precision: 0.5102, Val Recall: 0.5164, Val F1: 0.5068
# Epoch [165/2000], Loss: 0.3235, Train Accuracy: 0.8558, Train Precision: 0.8565, Train Recall: 0.8558, Train F1: 0.8560, Val Accuracy: 0.5191, Val Precision: 0.5131, Val Recall: 0.5191, Val F1: 0.5096
# Epoch [166/2000], Loss: 0.3192, Train Accuracy: 0.8558, Train Precision: 0.8558, Train Recall: 0.8558, Train F1: 0.8558, Val Accuracy: 0.5164, Val Precision: 0.5101, Val Recall: 0.5164, Val F1: 0.5064
# Epoch [167/2000], Loss: 0.3155, Train Accuracy: 0.8546, Train Precision: 0.8553, Train Recall: 0.8546, Train F1: 0.8548, Val Accuracy: 0.5164, Val Precision: 0.5102, Val Recall: 0.5164, Val F1: 0.5068
# Epoch [168/2000], Loss: 0.3129, Train Accuracy: 0.8558, Train Precision: 0.8563, Train Recall: 0.8558, Train F1: 0.8560, Val Accuracy: 0.5137, Val Precision: 0.5070, Val Recall: 0.5137, Val F1: 0.5032
# Epoch [169/2000], Loss: 0.3131, Train Accuracy: 0.8558, Train Precision: 0.8557, Train Recall: 0.8558, Train F1: 0.8557, Val Accuracy: 0.5260, Val Precision: 0.5207, Val Recall: 0.5260, Val F1: 0.5175
# Epoch [170/2000], Loss: 0.3189, Train Accuracy: 0.8505, Train Precision: 0.8526, Train Recall: 0.8505, Train F1: 0.8510, Val Accuracy: 0.5109, Val Precision: 0.5040, Val Recall: 0.5109, Val F1: 0.5004
# Epoch [171/2000], Loss: 0.3286, Train Accuracy: 0.8376, Train Precision: 0.8373, Train Recall: 0.8376, Train F1: 0.8373, Val Accuracy: 0.5150, Val Precision: 0.5108, Val Recall: 0.5150, Val F1: 0.5100
# Epoch [172/2000], Loss: 0.3238, Train Accuracy: 0.8435, Train Precision: 0.8484, Train Recall: 0.8435, Train F1: 0.8441, Val Accuracy: 0.5164, Val Precision: 0.5099, Val Recall: 0.5164, Val F1: 0.5060
# Epoch [173/2000], Loss: 0.3224, Train Accuracy: 0.8458, Train Precision: 0.8456, Train Recall: 0.8458, Train F1: 0.8456, Val Accuracy: 0.5150, Val Precision: 0.5096, Val Recall: 0.5150, Val F1: 0.5075
# Epoch [174/2000], Loss: 0.3321, Train Accuracy: 0.8329, Train Precision: 0.8358, Train Recall: 0.8329, Train F1: 0.8335, Val Accuracy: 0.5178, Val Precision: 0.5125, Val Recall: 0.5178, Val F1: 0.5102
# Epoch [175/2000], Loss: 0.3032, Train Accuracy: 0.8617, Train Precision: 0.8617, Train Recall: 0.8617, Train F1: 0.8617, Val Accuracy: 0.5164, Val Precision: 0.5098, Val Recall: 0.5164, Val F1: 0.5056
# Epoch [176/2000], Loss: 0.3197, Train Accuracy: 0.8470, Train Precision: 0.8471, Train Recall: 0.8470, Train F1: 0.8471, Val Accuracy: 0.5205, Val Precision: 0.5147, Val Recall: 0.5205, Val F1: 0.5112
# Epoch [177/2000], Loss: 0.2932, Train Accuracy: 0.8640, Train Precision: 0.8645, Train Recall: 0.8640, Train F1: 0.8642, Val Accuracy: 0.5109, Val Precision: 0.5057, Val Recall: 0.5109, Val F1: 0.5041
# Epoch [178/2000], Loss: 0.3057, Train Accuracy: 0.8552, Train Precision: 0.8565, Train Recall: 0.8552, Train F1: 0.8555, Val Accuracy: 0.5164, Val Precision: 0.5105, Val Recall: 0.5164, Val F1: 0.5076
# Epoch [179/2000], Loss: 0.2863, Train Accuracy: 0.8705, Train Precision: 0.8720, Train Recall: 0.8705, Train F1: 0.8708, Val Accuracy: 0.5191, Val Precision: 0.5126, Val Recall: 0.5191, Val F1: 0.5079
# Epoch [180/2000], Loss: 0.2937, Train Accuracy: 0.8634, Train Precision: 0.8633, Train Recall: 0.8634, Train F1: 0.8633, Val Accuracy: 0.5178, Val Precision: 0.5122, Val Recall: 0.5178, Val F1: 0.5095
# Epoch [181/2000], Loss: 0.2790, Train Accuracy: 0.8734, Train Precision: 0.8744, Train Recall: 0.8734, Train F1: 0.8736, Val Accuracy: 0.5232, Val Precision: 0.5186, Val Recall: 0.5232, Val F1: 0.5168
# Epoch [182/2000], Loss: 0.2841, Train Accuracy: 0.8693, Train Precision: 0.8723, Train Recall: 0.8693, Train F1: 0.8697, Val Accuracy: 0.5109, Val Precision: 0.5042, Val Recall: 0.5109, Val F1: 0.5008
# Epoch [183/2000], Loss: 0.2757, Train Accuracy: 0.8775, Train Precision: 0.8774, Train Recall: 0.8775, Train F1: 0.8774, Val Accuracy: 0.5219, Val Precision: 0.5159, Val Recall: 0.5219, Val F1: 0.5120
# Epoch [184/2000], Loss: 0.2731, Train Accuracy: 0.8757, Train Precision: 0.8783, Train Recall: 0.8757, Train F1: 0.8761, Val Accuracy: 0.5273, Val Precision: 0.5220, Val Recall: 0.5273, Val F1: 0.5183
# Epoch [185/2000], Loss: 0.2733, Train Accuracy: 0.8787, Train Precision: 0.8786, Train Recall: 0.8787, Train F1: 0.8783, Val Accuracy: 0.5178, Val Precision: 0.5120, Val Recall: 0.5178, Val F1: 0.5091
# Epoch [186/2000], Loss: 0.2677, Train Accuracy: 0.8751, Train Precision: 0.8783, Train Recall: 0.8751, Train F1: 0.8756, Val Accuracy: 0.5178, Val Precision: 0.5119, Val Recall: 0.5178, Val F1: 0.5088
# Epoch [187/2000], Loss: 0.2672, Train Accuracy: 0.8857, Train Precision: 0.8856, Train Recall: 0.8857, Train F1: 0.8854, Val Accuracy: 0.5205, Val Precision: 0.5149, Val Recall: 0.5205, Val F1: 0.5119
# Epoch [188/2000], Loss: 0.2601, Train Accuracy: 0.8816, Train Precision: 0.8845, Train Recall: 0.8816, Train F1: 0.8820, Val Accuracy: 0.5205, Val Precision: 0.5144, Val Recall: 0.5205, Val F1: 0.5104
# Epoch [189/2000], Loss: 0.2581, Train Accuracy: 0.8875, Train Precision: 0.8873, Train Recall: 0.8875, Train F1: 0.8872, Val Accuracy: 0.5205, Val Precision: 0.5152, Val Recall: 0.5205, Val F1: 0.5126
# Epoch [190/2000], Loss: 0.2510, Train Accuracy: 0.8945, Train Precision: 0.8956, Train Recall: 0.8945, Train F1: 0.8947, Val Accuracy: 0.5219, Val Precision: 0.5163, Val Recall: 0.5219, Val F1: 0.5131
# Epoch [191/2000], Loss: 0.2487, Train Accuracy: 0.8939, Train Precision: 0.8939, Train Recall: 0.8939, Train F1: 0.8939, Val Accuracy: 0.5178, Val Precision: 0.5116, Val Recall: 0.5178, Val F1: 0.5080
# Epoch [192/2000], Loss: 0.2462, Train Accuracy: 0.8927, Train Precision: 0.8933, Train Recall: 0.8927, Train F1: 0.8929, Val Accuracy: 0.5232, Val Precision: 0.5181, Val Recall: 0.5232, Val F1: 0.5154
# Epoch [193/2000], Loss: 0.2431, Train Accuracy: 0.8927, Train Precision: 0.8929, Train Recall: 0.8927, Train F1: 0.8928, Val Accuracy: 0.5191, Val Precision: 0.5134, Val Recall: 0.5191, Val F1: 0.5103
# Epoch [194/2000], Loss: 0.2401, Train Accuracy: 0.8962, Train Precision: 0.8976, Train Recall: 0.8962, Train F1: 0.8965, Val Accuracy: 0.5150, Val Precision: 0.5091, Val Recall: 0.5150, Val F1: 0.5064
# Epoch [195/2000], Loss: 0.2387, Train Accuracy: 0.9015, Train Precision: 0.9014, Train Recall: 0.9015, Train F1: 0.9014, Val Accuracy: 0.5178, Val Precision: 0.5129, Val Recall: 0.5178, Val F1: 0.5112
# Epoch [196/2000], Loss: 0.2551, Train Accuracy: 0.8822, Train Precision: 0.8915, Train Recall: 0.8822, Train F1: 0.8827, Val Accuracy: 0.5219, Val Precision: 0.5154, Val Recall: 0.5219, Val F1: 0.5103
# Epoch [197/2000], Loss: 0.3357, Train Accuracy: 0.8406, Train Precision: 0.8548, Train Recall: 0.8406, Train F1: 0.8358, Val Accuracy: 0.5150, Val Precision: 0.5122, Val Recall: 0.5150, Val F1: 0.5123
# Epoch [198/2000], Loss: 0.3862, Train Accuracy: 0.8165, Train Precision: 0.8527, Train Recall: 0.8165, Train F1: 0.8162, Val Accuracy: 0.5150, Val Precision: 0.5077, Val Recall: 0.5150, Val F1: 0.5026
# Epoch [199/2000], Loss: 0.2585, Train Accuracy: 0.8769, Train Precision: 0.8772, Train Recall: 0.8769, Train F1: 0.8770, Val Accuracy: 0.5246, Val Precision: 0.5173, Val Recall: 0.5246, Val F1: 0.5089
# Epoch [200/2000], Loss: 0.3155, Train Accuracy: 0.8535, Train Precision: 0.8623, Train Recall: 0.8535, Train F1: 0.8503, Val Accuracy: 0.5273, Val Precision: 0.5232, Val Recall: 0.5273, Val F1: 0.5217
# Epoch [201/2000], Loss: 0.2772, Train Accuracy: 0.8716, Train Precision: 0.8718, Train Recall: 0.8716, Train F1: 0.8710, Val Accuracy: 0.5219, Val Precision: 0.5190, Val Recall: 0.5219, Val F1: 0.5190
# Epoch [202/2000], Loss: 0.2759, Train Accuracy: 0.8675, Train Precision: 0.8735, Train Recall: 0.8675, Train F1: 0.8681, Val Accuracy: 0.5150, Val Precision: 0.5096, Val Recall: 0.5150, Val F1: 0.5075
# Epoch [203/2000], Loss: 0.2720, Train Accuracy: 0.8710, Train Precision: 0.8775, Train Recall: 0.8710, Train F1: 0.8716, Val Accuracy: 0.5287, Val Precision: 0.5222, Val Recall: 0.5287, Val F1: 0.5148
# Epoch [204/2000], Loss: 0.2732, Train Accuracy: 0.8775, Train Precision: 0.8786, Train Recall: 0.8775, Train F1: 0.8778, Val Accuracy: 0.5246, Val Precision: 0.5188, Val Recall: 0.5246, Val F1: 0.5147
# Epoch [205/2000], Loss: 0.2484, Train Accuracy: 0.8898, Train Precision: 0.8897, Train Recall: 0.8898, Train F1: 0.8896, Val Accuracy: 0.5287, Val Precision: 0.5247, Val Recall: 0.5287, Val F1: 0.5232
# Epoch [206/2000], Loss: 0.2627, Train Accuracy: 0.8757, Train Precision: 0.8759, Train Recall: 0.8757, Train F1: 0.8752, Val Accuracy: 0.5287, Val Precision: 0.5253, Val Recall: 0.5287, Val F1: 0.5246
# Epoch [207/2000], Loss: 0.2545, Train Accuracy: 0.8834, Train Precision: 0.8836, Train Recall: 0.8834, Train F1: 0.8828, Val Accuracy: 0.5260, Val Precision: 0.5216, Val Recall: 0.5260, Val F1: 0.5199
# Epoch [208/2000], Loss: 0.2406, Train Accuracy: 0.8957, Train Precision: 0.8955, Train Recall: 0.8957, Train F1: 0.8955, Val Accuracy: 0.5246, Val Precision: 0.5192, Val Recall: 0.5246, Val F1: 0.5159
# Epoch [209/2000], Loss: 0.2421, Train Accuracy: 0.8898, Train Precision: 0.8905, Train Recall: 0.8898, Train F1: 0.8900, Val Accuracy: 0.5260, Val Precision: 0.5204, Val Recall: 0.5260, Val F1: 0.5163
# Epoch [210/2000], Loss: 0.2415, Train Accuracy: 0.8863, Train Precision: 0.8880, Train Recall: 0.8863, Train F1: 0.8866, Val Accuracy: 0.5273, Val Precision: 0.5222, Val Recall: 0.5273, Val F1: 0.5191
# Epoch [211/2000], Loss: 0.2304, Train Accuracy: 0.8980, Train Precision: 0.8992, Train Recall: 0.8980, Train F1: 0.8982, Val Accuracy: 0.5301, Val Precision: 0.5252, Val Recall: 0.5301, Val F1: 0.5222
# Epoch [212/2000], Loss: 0.2307, Train Accuracy: 0.8980, Train Precision: 0.8982, Train Recall: 0.8980, Train F1: 0.8981, Val Accuracy: 0.5287, Val Precision: 0.5241, Val Recall: 0.5287, Val F1: 0.5217
# Epoch [213/2000], Loss: 0.2295, Train Accuracy: 0.9056, Train Precision: 0.9056, Train Recall: 0.9056, Train F1: 0.9054, Val Accuracy: 0.5219, Val Precision: 0.5167, Val Recall: 0.5219, Val F1: 0.5142
# Epoch [214/2000], Loss: 0.2225, Train Accuracy: 0.9050, Train Precision: 0.9055, Train Recall: 0.9050, Train F1: 0.9046, Val Accuracy: 0.5260, Val Precision: 0.5210, Val Recall: 0.5260, Val F1: 0.5182
# Epoch [215/2000], Loss: 0.2197, Train Accuracy: 0.9045, Train Precision: 0.9045, Train Recall: 0.9045, Train F1: 0.9042, Val Accuracy: 0.5246, Val Precision: 0.5198, Val Recall: 0.5246, Val F1: 0.5177
# Epoch [216/2000], Loss: 0.2164, Train Accuracy: 0.9109, Train Precision: 0.9112, Train Recall: 0.9109, Train F1: 0.9110, Val Accuracy: 0.5260, Val Precision: 0.5215, Val Recall: 0.5260, Val F1: 0.5195
# Epoch [217/2000], Loss: 0.2133, Train Accuracy: 0.9097, Train Precision: 0.9108, Train Recall: 0.9097, Train F1: 0.9099, Val Accuracy: 0.5287, Val Precision: 0.5241, Val Recall: 0.5287, Val F1: 0.5217
# Epoch [218/2000], Loss: 0.2106, Train Accuracy: 0.9103, Train Precision: 0.9109, Train Recall: 0.9103, Train F1: 0.9105, Val Accuracy: 0.5273, Val Precision: 0.5220, Val Recall: 0.5273, Val F1: 0.5183
# Epoch [219/2000], Loss: 0.2078, Train Accuracy: 0.9097, Train Precision: 0.9097, Train Recall: 0.9097, Train F1: 0.9097, Val Accuracy: 0.5246, Val Precision: 0.5186, Val Recall: 0.5246, Val F1: 0.5139
# Epoch [220/2000], Loss: 0.2050, Train Accuracy: 0.9109, Train Precision: 0.9108, Train Recall: 0.9109, Train F1: 0.9108, Val Accuracy: 0.5205, Val Precision: 0.5141, Val Recall: 0.5205, Val F1: 0.5095
# Epoch [221/2000], Loss: 0.2008, Train Accuracy: 0.9132, Train Precision: 0.9132, Train Recall: 0.9132, Train F1: 0.9132, Val Accuracy: 0.5232, Val Precision: 0.5172, Val Recall: 0.5232, Val F1: 0.5127
# Epoch [222/2000], Loss: 0.1976, Train Accuracy: 0.9150, Train Precision: 0.9153, Train Recall: 0.9150, Train F1: 0.9151, Val Accuracy: 0.5260, Val Precision: 0.5205, Val Recall: 0.5260, Val F1: 0.5167
# Epoch [223/2000], Loss: 0.1952, Train Accuracy: 0.9162, Train Precision: 0.9166, Train Recall: 0.9162, Train F1: 0.9163, Val Accuracy: 0.5260, Val Precision: 0.5205, Val Recall: 0.5260, Val F1: 0.5167
# Epoch [224/2000], Loss: 0.1923, Train Accuracy: 0.9191, Train Precision: 0.9193, Train Recall: 0.9191, Train F1: 0.9192, Val Accuracy: 0.5273, Val Precision: 0.5217, Val Recall: 0.5273, Val F1: 0.5171
# Epoch [225/2000], Loss: 0.1887, Train Accuracy: 0.9203, Train Precision: 0.9203, Train Recall: 0.9203, Train F1: 0.9203, Val Accuracy: 0.5273, Val Precision: 0.5217, Val Recall: 0.5273, Val F1: 0.5171
# Epoch [226/2000], Loss: 0.1861, Train Accuracy: 0.9238, Train Precision: 0.9238, Train Recall: 0.9238, Train F1: 0.9238, Val Accuracy: 0.5287, Val Precision: 0.5232, Val Recall: 0.5287, Val F1: 0.5187
# Epoch [227/2000], Loss: 0.1834, Train Accuracy: 0.9244, Train Precision: 0.9245, Train Recall: 0.9244, Train F1: 0.9244, Val Accuracy: 0.5287, Val Precision: 0.5231, Val Recall: 0.5287, Val F1: 0.5183
# Epoch [228/2000], Loss: 0.1799, Train Accuracy: 0.9279, Train Precision: 0.9281, Train Recall: 0.9279, Train F1: 0.9280, Val Accuracy: 0.5342, Val Precision: 0.5289, Val Recall: 0.5342, Val F1: 0.5235
# Epoch [229/2000], Loss: 0.1777, Train Accuracy: 0.9297, Train Precision: 0.9299, Train Recall: 0.9297, Train F1: 0.9297, Val Accuracy: 0.5328, Val Precision: 0.5275, Val Recall: 0.5328, Val F1: 0.5227
# Epoch [230/2000], Loss: 0.1739, Train Accuracy: 0.9308, Train Precision: 0.9310, Train Recall: 0.9308, Train F1: 0.9309, Val Accuracy: 0.5273, Val Precision: 0.5217, Val Recall: 0.5273, Val F1: 0.5171
# Epoch [231/2000], Loss: 0.1714, Train Accuracy: 0.9297, Train Precision: 0.9296, Train Recall: 0.9297, Train F1: 0.9296, Val Accuracy: 0.5287, Val Precision: 0.5231, Val Recall: 0.5287, Val F1: 0.5183
# Epoch [232/2000], Loss: 0.1685, Train Accuracy: 0.9314, Train Precision: 0.9315, Train Recall: 0.9314, Train F1: 0.9314, Val Accuracy: 0.5287, Val Precision: 0.5231, Val Recall: 0.5287, Val F1: 0.5183
# ...
# Epoch [1922/2000], Loss: 0.0001, Train Accuracy: 1.0000, Train Precision: 1.0000, Train Recall: 1.0000, Train F1: 1.0000, Val Accuracy: 0.5055, Val Precision: 0.4947, Val Recall: 0.5055, Val F1: 0.4863
# Epoch [1923/2000], Loss: 0.0001, Train Accuracy: 1.0000, Train Precision: 1.0000, Train Recall: 1.0000, Train F1: 1.0000, Val Accuracy: 0.5055, Val Precision: 0.4947, Val Recall: 0.5055, Val F1: 0.4863
# Epoch [1924/2000], Loss: 0.0001, Train Accuracy: 1.0000, Train Precision: 1.0000, Train Recall: 1.0000, Train F1: 1.0000, Val Accuracy: 0.5055, Val Precision: 0.4947, Val Recall: 0.5055, Val F1: 0.4863
# Epoch [1925/2000], Loss: 0.0001, Train Accuracy: 1.0000, Train Precision: 1.0000, Train Recall: 1.0000, Train F1: 1.0000, Val Accuracy: 0.5055, Val Precision: 0.4947, Val Recall: 0.5055, Val F1: 0.4863
# Epoch [1926/2000], Loss: 0.0001, Train Accuracy: 1.0000, Train Precision: 1.0000, Train Recall: 1.0000, Train F1: 1.0000, Val Accuracy: 0.5055, Val Precision: 0.4947, Val Recall: 0.5055, Val F1: 0.4863
# Epoch [1927/2000], Loss: 0.0001, Train Accuracy: 1.0000, Train Precision: 1.0000, Train Recall: 1.0000, Train F1: 1.0000, Val Accuracy: 0.5055, Val Precision: 0.4947, Val Recall: 0.5055, Val F1: 0.4863
# Epoch [1928/2000], Loss: 0.0001, Train Accuracy: 1.0000, Train Precision: 1.0000, Train Recall: 1.0000, Train F1: 1.0000, Val Accuracy: 0.5055, Val Precision: 0.4947, Val Recall: 0.5055, Val F1: 0.4863
# Epoch [1929/2000], Loss: 0.0001, Train Accuracy: 1.0000, Train Precision: 1.0000, Train Recall: 1.0000, Train F1: 1.0000, Val Accuracy: 0.5055, Val Precision: 0.4947, Val Recall: 0.5055, Val F1: 0.4863
# Epoch [1930/2000], Loss: 0.0001, Train Accuracy: 1.0000, Train Precision: 1.0000, Train Recall: 1.0000, Train F1: 1.0000, Val Accuracy: 0.5055, Val Precision: 0.4947, Val Recall: 0.5055, Val F1: 0.4863
# Epoch [1931/2000], Loss: 0.0001, Train Accuracy: 1.0000, Train Precision: 1.0000, Train Recall: 1.0000, Train F1: 1.0000, Val Accuracy: 0.5055, Val Precision: 0.4947, Val Recall: 0.5055, Val F1: 0.4863
# Epoch [1932/2000], Loss: 0.0001, Train Accuracy: 1.0000, Train Precision: 1.0000, Train Recall: 1.0000, Train F1: 1.0000, Val Accuracy: 0.5055, Val Precision: 0.4947, Val Recall: 0.5055, Val F1: 0.4863
# Epoch [1933/2000], Loss: 0.0001, Train Accuracy: 1.0000, Train Precision: 1.0000, Train Recall: 1.0000, Train F1: 1.0000, Val Accuracy: 0.5055, Val Precision: 0.4947, Val Recall: 0.5055, Val F1: 0.4863
# Epoch [1934/2000], Loss: 0.0001, Train Accuracy: 1.0000, Train Precision: 1.0000, Train Recall: 1.0000, Train F1: 1.0000, Val Accuracy: 0.5055, Val Precision: 0.4947, Val Recall: 0.5055, Val F1: 0.4863
# Epoch [1935/2000], Loss: 0.0001, Train Accuracy: 1.0000, Train Precision: 1.0000, Train Recall: 1.0000, Train F1: 1.0000, Val Accuracy: 0.5055, Val Precision: 0.4947, Val Recall: 0.5055, Val F1: 0.4863
# Epoch [1936/2000], Loss: 0.0001, Train Accuracy: 1.0000, Train Precision: 1.0000, Train Recall: 1.0000, Train F1: 1.0000, Val Accuracy: 0.5055, Val Precision: 0.4947, Val Recall: 0.5055, Val F1: 0.4863
# Epoch [1937/2000], Loss: 0.0001, Train Accuracy: 1.0000, Train Precision: 1.0000, Train Recall: 1.0000, Train F1: 1.0000, Val Accuracy: 0.5055, Val Precision: 0.4947, Val Recall: 0.5055, Val F1: 0.4863
# Epoch [1938/2000], Loss: 0.0001, Train Accuracy: 1.0000, Train Precision: 1.0000, Train Recall: 1.0000, Train F1: 1.0000, Val Accuracy: 0.5055, Val Precision: 0.4947, Val Recall: 0.5055, Val F1: 0.4863
# Epoch [1939/2000], Loss: 0.0001, Train Accuracy: 1.0000, Train Precision: 1.0000, Train Recall: 1.0000, Train F1: 1.0000, Val Accuracy: 0.5055, Val Precision: 0.4947, Val Recall: 0.5055, Val F1: 0.4863
# Epoch [1940/2000], Loss: 0.0001, Train Accuracy: 1.0000, Train Precision: 1.0000, Train Recall: 1.0000, Train F1: 1.0000, Val Accuracy: 0.5055, Val Precision: 0.4947, Val Recall: 0.5055, Val F1: 0.4863
# Epoch [1941/2000], Loss: 0.0001, Train Accuracy: 1.0000, Train Precision: 1.0000, Train Recall: 1.0000, Train F1: 1.0000, Val Accuracy: 0.5055, Val Precision: 0.4947, Val Recall: 0.5055, Val F1: 0.4863
# Epoch [1942/2000], Loss: 0.0001, Train Accuracy: 1.0000, Train Precision: 1.0000, Train Recall: 1.0000, Train F1: 1.0000, Val Accuracy: 0.5055, Val Precision: 0.4947, Val Recall: 0.5055, Val F1: 0.4863
# Epoch [1943/2000], Loss: 0.0001, Train Accuracy: 1.0000, Train Precision: 1.0000, Train Recall: 1.0000, Train F1: 1.0000, Val Accuracy: 0.5055, Val Precision: 0.4947, Val Recall: 0.5055, Val F1: 0.4863
# Epoch [1944/2000], Loss: 0.0001, Train Accuracy: 1.0000, Train Precision: 1.0000, Train Recall: 1.0000, Train F1: 1.0000, Val Accuracy: 0.5055, Val Precision: 0.4947, Val Recall: 0.5055, Val F1: 0.4863
# Epoch [1945/2000], Loss: 0.0001, Train Accuracy: 1.0000, Train Precision: 1.0000, Train Recall: 1.0000, Train F1: 1.0000, Val Accuracy: 0.5055, Val Precision: 0.4947, Val Recall: 0.5055, Val F1: 0.4863
# Epoch [1946/2000], Loss: 0.0001, Train Accuracy: 1.0000, Train Precision: 1.0000, Train Recall: 1.0000, Train F1: 1.0000, Val Accuracy: 0.5055, Val Precision: 0.4947, Val Recall: 0.5055, Val F1: 0.4863
# Epoch [1947/2000], Loss: 0.0001, Train Accuracy: 1.0000, Train Precision: 1.0000, Train Recall: 1.0000, Train F1: 1.0000, Val Accuracy: 0.5055, Val Precision: 0.4947, Val Recall: 0.5055, Val F1: 0.4863
# Epoch [1948/2000], Loss: 0.0001, Train Accuracy: 1.0000, Train Precision: 1.0000, Train Recall: 1.0000, Train F1: 1.0000, Val Accuracy: 0.5055, Val Precision: 0.4947, Val Recall: 0.5055, Val F1: 0.4863
# Epoch [1949/2000], Loss: 0.0001, Train Accuracy: 1.0000, Train Precision: 1.0000, Train Recall: 1.0000, Train F1: 1.0000, Val Accuracy: 0.5055, Val Precision: 0.4947, Val Recall: 0.5055, Val F1: 0.4863
# Epoch [1950/2000], Loss: 0.0001, Train Accuracy: 1.0000, Train Precision: 1.0000, Train Recall: 1.0000, Train F1: 1.0000, Val Accuracy: 0.5055, Val Precision: 0.4947, Val Recall: 0.5055, Val F1: 0.4863
# Epoch [1951/2000], Loss: 0.0001, Train Accuracy: 1.0000, Train Precision: 1.0000, Train Recall: 1.0000, Train F1: 1.0000, Val Accuracy: 0.5055, Val Precision: 0.4947, Val Recall: 0.5055, Val F1: 0.4863
# Epoch [1952/2000], Loss: 0.0001, Train Accuracy: 1.0000, Train Precision: 1.0000, Train Recall: 1.0000, Train F1: 1.0000, Val Accuracy: 0.5055, Val Precision: 0.4947, Val Recall: 0.5055, Val F1: 0.4863
# Epoch [1953/2000], Loss: 0.0001, Train Accuracy: 1.0000, Train Precision: 1.0000, Train Recall: 1.0000, Train F1: 1.0000, Val Accuracy: 0.5055, Val Precision: 0.4947, Val Recall: 0.5055, Val F1: 0.4863
# Epoch [1954/2000], Loss: 0.0001, Train Accuracy: 1.0000, Train Precision: 1.0000, Train Recall: 1.0000, Train F1: 1.0000, Val Accuracy: 0.5055, Val Precision: 0.4947, Val Recall: 0.5055, Val F1: 0.4863
# Epoch [1955/2000], Loss: 0.0001, Train Accuracy: 1.0000, Train Precision: 1.0000, Train Recall: 1.0000, Train F1: 1.0000, Val Accuracy: 0.5055, Val Precision: 0.4947, Val Recall: 0.5055, Val F1: 0.4863
# Epoch [1956/2000], Loss: 0.0001, Train Accuracy: 1.0000, Train Precision: 1.0000, Train Recall: 1.0000, Train F1: 1.0000, Val Accuracy: 0.5055, Val Precision: 0.4947, Val Recall: 0.5055, Val F1: 0.4863
# Epoch [1957/2000], Loss: 0.0001, Train Accuracy: 1.0000, Train Precision: 1.0000, Train Recall: 1.0000, Train F1: 1.0000, Val Accuracy: 0.5055, Val Precision: 0.4947, Val Recall: 0.5055, Val F1: 0.4863
# Epoch [1958/2000], Loss: 0.0001, Train Accuracy: 1.0000, Train Precision: 1.0000, Train Recall: 1.0000, Train F1: 1.0000, Val Accuracy: 0.5055, Val Precision: 0.4947, Val Recall: 0.5055, Val F1: 0.4863
# Epoch [1959/2000], Loss: 0.0001, Train Accuracy: 1.0000, Train Precision: 1.0000, Train Recall: 1.0000, Train F1: 1.0000, Val Accuracy: 0.5055, Val Precision: 0.4947, Val Recall: 0.5055, Val F1: 0.4863
# Epoch [1960/2000], Loss: 0.0001, Train Accuracy: 1.0000, Train Precision: 1.0000, Train Recall: 1.0000, Train F1: 1.0000, Val Accuracy: 0.5055, Val Precision: 0.4947, Val Recall: 0.5055, Val F1: 0.4863
# Epoch [1961/2000], Loss: 0.0001, Train Accuracy: 1.0000, Train Precision: 1.0000, Train Recall: 1.0000, Train F1: 1.0000, Val Accuracy: 0.5055, Val Precision: 0.4947, Val Recall: 0.5055, Val F1: 0.4863
# Epoch [1962/2000], Loss: 0.0001, Train Accuracy: 1.0000, Train Precision: 1.0000, Train Recall: 1.0000, Train F1: 1.0000, Val Accuracy: 0.5055, Val Precision: 0.4947, Val Recall: 0.5055, Val F1: 0.4863
# Epoch [1963/2000], Loss: 0.0001, Train Accuracy: 1.0000, Train Precision: 1.0000, Train Recall: 1.0000, Train F1: 1.0000, Val Accuracy: 0.5055, Val Precision: 0.4947, Val Recall: 0.5055, Val F1: 0.4863
# Epoch [1964/2000], Loss: 0.0001, Train Accuracy: 1.0000, Train Precision: 1.0000, Train Recall: 1.0000, Train F1: 1.0000, Val Accuracy: 0.5055, Val Precision: 0.4947, Val Recall: 0.5055, Val F1: 0.4863
# Epoch [1965/2000], Loss: 0.0001, Train Accuracy: 1.0000, Train Precision: 1.0000, Train Recall: 1.0000, Train F1: 1.0000, Val Accuracy: 0.5055, Val Precision: 0.4947, Val Recall: 0.5055, Val F1: 0.4863
# Epoch [1966/2000], Loss: 0.0001, Train Accuracy: 1.0000, Train Precision: 1.0000, Train Recall: 1.0000, Train F1: 1.0000, Val Accuracy: 0.5055, Val Precision: 0.4947, Val Recall: 0.5055, Val F1: 0.4863
# Epoch [1967/2000], Loss: 0.0001, Train Accuracy: 1.0000, Train Precision: 1.0000, Train Recall: 1.0000, Train F1: 1.0000, Val Accuracy: 0.5055, Val Precision: 0.4947, Val Recall: 0.5055, Val F1: 0.4863
# Epoch [1968/2000], Loss: 0.0001, Train Accuracy: 1.0000, Train Precision: 1.0000, Train Recall: 1.0000, Train F1: 1.0000, Val Accuracy: 0.5055, Val Precision: 0.4947, Val Recall: 0.5055, Val F1: 0.4863
# Epoch [1969/2000], Loss: 0.0001, Train Accuracy: 1.0000, Train Precision: 1.0000, Train Recall: 1.0000, Train F1: 1.0000, Val Accuracy: 0.5055, Val Precision: 0.4947, Val Recall: 0.5055, Val F1: 0.4863
# Epoch [1970/2000], Loss: 0.0001, Train Accuracy: 1.0000, Train Precision: 1.0000, Train Recall: 1.0000, Train F1: 1.0000, Val Accuracy: 0.5055, Val Precision: 0.4947, Val Recall: 0.5055, Val F1: 0.4863
# Epoch [1971/2000], Loss: 0.0001, Train Accuracy: 1.0000, Train Precision: 1.0000, Train Recall: 1.0000, Train F1: 1.0000, Val Accuracy: 0.5055, Val Precision: 0.4947, Val Recall: 0.5055, Val F1: 0.4863
# Epoch [1972/2000], Loss: 0.0001, Train Accuracy: 1.0000, Train Precision: 1.0000, Train Recall: 1.0000, Train F1: 1.0000, Val Accuracy: 0.5055, Val Precision: 0.4947, Val Recall: 0.5055, Val F1: 0.4863
# Epoch [1973/2000], Loss: 0.0001, Train Accuracy: 1.0000, Train Precision: 1.0000, Train Recall: 1.0000, Train F1: 1.0000, Val Accuracy: 0.5055, Val Precision: 0.4947, Val Recall: 0.5055, Val F1: 0.4863
# Epoch [1974/2000], Loss: 0.0001, Train Accuracy: 1.0000, Train Precision: 1.0000, Train Recall: 1.0000, Train F1: 1.0000, Val Accuracy: 0.5055, Val Precision: 0.4947, Val Recall: 0.5055, Val F1: 0.4863
# Epoch [1975/2000], Loss: 0.0001, Train Accuracy: 1.0000, Train Precision: 1.0000, Train Recall: 1.0000, Train F1: 1.0000, Val Accuracy: 0.5055, Val Precision: 0.4947, Val Recall: 0.5055, Val F1: 0.4863
# Epoch [1976/2000], Loss: 0.0001, Train Accuracy: 1.0000, Train Precision: 1.0000, Train Recall: 1.0000, Train F1: 1.0000, Val Accuracy: 0.5055, Val Precision: 0.4947, Val Recall: 0.5055, Val F1: 0.4863
# Epoch [1977/2000], Loss: 0.0001, Train Accuracy: 1.0000, Train Precision: 1.0000, Train Recall: 1.0000, Train F1: 1.0000, Val Accuracy: 0.5055, Val Precision: 0.4947, Val Recall: 0.5055, Val F1: 0.4863
# Epoch [1978/2000], Loss: 0.0001, Train Accuracy: 1.0000, Train Precision: 1.0000, Train Recall: 1.0000, Train F1: 1.0000, Val Accuracy: 0.5055, Val Precision: 0.4947, Val Recall: 0.5055, Val F1: 0.4863
# Epoch [1979/2000], Loss: 0.0001, Train Accuracy: 1.0000, Train Precision: 1.0000, Train Recall: 1.0000, Train F1: 1.0000, Val Accuracy: 0.5055, Val Precision: 0.4947, Val Recall: 0.5055, Val F1: 0.4863
# Epoch [1980/2000], Loss: 0.0001, Train Accuracy: 1.0000, Train Precision: 1.0000, Train Recall: 1.0000, Train F1: 1.0000, Val Accuracy: 0.5055, Val Precision: 0.4947, Val Recall: 0.5055, Val F1: 0.4863
# Epoch [1981/2000], Loss: 0.0001, Train Accuracy: 1.0000, Train Precision: 1.0000, Train Recall: 1.0000, Train F1: 1.0000, Val Accuracy: 0.5055, Val Precision: 0.4947, Val Recall: 0.5055, Val F1: 0.4863
# Epoch [1982/2000], Loss: 0.0001, Train Accuracy: 1.0000, Train Precision: 1.0000, Train Recall: 1.0000, Train F1: 1.0000, Val Accuracy: 0.5055, Val Precision: 0.4947, Val Recall: 0.5055, Val F1: 0.4863
# Epoch [1983/2000], Loss: 0.0001, Train Accuracy: 1.0000, Train Precision: 1.0000, Train Recall: 1.0000, Train F1: 1.0000, Val Accuracy: 0.5055, Val Precision: 0.4947, Val Recall: 0.5055, Val F1: 0.4863
# Epoch [1984/2000], Loss: 0.0001, Train Accuracy: 1.0000, Train Precision: 1.0000, Train Recall: 1.0000, Train F1: 1.0000, Val Accuracy: 0.5055, Val Precision: 0.4947, Val Recall: 0.5055, Val F1: 0.4863
# Epoch [1985/2000], Loss: 0.0001, Train Accuracy: 1.0000, Train Precision: 1.0000, Train Recall: 1.0000, Train F1: 1.0000, Val Accuracy: 0.5055, Val Precision: 0.4947, Val Recall: 0.5055, Val F1: 0.4863
# Epoch [1986/2000], Loss: 0.0001, Train Accuracy: 1.0000, Train Precision: 1.0000, Train Recall: 1.0000, Train F1: 1.0000, Val Accuracy: 0.5055, Val Precision: 0.4947, Val Recall: 0.5055, Val F1: 0.4863
# Epoch [1987/2000], Loss: 0.0001, Train Accuracy: 1.0000, Train Precision: 1.0000, Train Recall: 1.0000, Train F1: 1.0000, Val Accuracy: 0.5055, Val Precision: 0.4947, Val Recall: 0.5055, Val F1: 0.4863
# Epoch [1988/2000], Loss: 0.0001, Train Accuracy: 1.0000, Train Precision: 1.0000, Train Recall: 1.0000, Train F1: 1.0000, Val Accuracy: 0.5055, Val Precision: 0.4947, Val Recall: 0.5055, Val F1: 0.4863
# Epoch [1989/2000], Loss: 0.0001, Train Accuracy: 1.0000, Train Precision: 1.0000, Train Recall: 1.0000, Train F1: 1.0000, Val Accuracy: 0.5055, Val Precision: 0.4947, Val Recall: 0.5055, Val F1: 0.4863
# Epoch [1990/2000], Loss: 0.0001, Train Accuracy: 1.0000, Train Precision: 1.0000, Train Recall: 1.0000, Train F1: 1.0000, Val Accuracy: 0.5055, Val Precision: 0.4947, Val Recall: 0.5055, Val F1: 0.4863
# Epoch [1991/2000], Loss: 0.0001, Train Accuracy: 1.0000, Train Precision: 1.0000, Train Recall: 1.0000, Train F1: 1.0000, Val Accuracy: 0.5055, Val Precision: 0.4947, Val Recall: 0.5055, Val F1: 0.4863
# Epoch [1992/2000], Loss: 0.0001, Train Accuracy: 1.0000, Train Precision: 1.0000, Train Recall: 1.0000, Train F1: 1.0000, Val Accuracy: 0.5055, Val Precision: 0.4947, Val Recall: 0.5055, Val F1: 0.4863
# Epoch [1993/2000], Loss: 0.0001, Train Accuracy: 1.0000, Train Precision: 1.0000, Train Recall: 1.0000, Train F1: 1.0000, Val Accuracy: 0.5055, Val Precision: 0.4947, Val Recall: 0.5055, Val F1: 0.4863
# Epoch [1994/2000], Loss: 0.0001, Train Accuracy: 1.0000, Train Precision: 1.0000, Train Recall: 1.0000, Train F1: 1.0000, Val Accuracy: 0.5055, Val Precision: 0.4947, Val Recall: 0.5055, Val F1: 0.4863
# Epoch [1995/2000], Loss: 0.0001, Train Accuracy: 1.0000, Train Precision: 1.0000, Train Recall: 1.0000, Train F1: 1.0000, Val Accuracy: 0.5055, Val Precision: 0.4947, Val Recall: 0.5055, Val F1: 0.4863
# Epoch [1996/2000], Loss: 0.0001, Train Accuracy: 1.0000, Train Precision: 1.0000, Train Recall: 1.0000, Train F1: 1.0000, Val Accuracy: 0.5055, Val Precision: 0.4947, Val Recall: 0.5055, Val F1: 0.4863
# Epoch [1997/2000], Loss: 0.0001, Train Accuracy: 1.0000, Train Precision: 1.0000, Train Recall: 1.0000, Train F1: 1.0000, Val Accuracy: 0.5068, Val Precision: 0.4961, Val Recall: 0.5068, Val F1: 0.4875
# Epoch [1998/2000], Loss: 0.0001, Train Accuracy: 1.0000, Train Precision: 1.0000, Train Recall: 1.0000, Train F1: 1.0000, Val Accuracy: 0.5068, Val Precision: 0.4961, Val Recall: 0.5068, Val F1: 0.4875
# Epoch [1999/2000], Loss: 0.0001, Train Accuracy: 1.0000, Train Precision: 1.0000, Train Recall: 1.0000, Train F1: 1.0000, Val Accuracy: 0.5068, Val Precision: 0.4961, Val Recall: 0.5068, Val F1: 0.4875
# Epoch [2000/2000], Loss: 0.0001, Train Accuracy: 1.0000, Train Precision: 1.0000, Train Recall: 1.0000, Train F1: 1.0000, Val Accuracy: 0.5068, Val Precision: 0.4961, Val Recall: 0.5068, Val F1: 0.4875

# %%
### LOAD THE BEST MDOEL
# LOAD LSTM MODEL STATE DICT  
model.load_state_dict(torch.load(f = best_model_pathname ))
# Out:
# <All keys matched successfully>

# %%
# Evaluate model
model.eval()
with torch.no_grad():
    predictions = model(X_test).argmax(dim=1)
    accuracy = accuracy_score(y_test, predictions)
    print(f"Test Accuracy: {accuracy:.2f}")
# Out:
# Test Accuracy: 0.55

# %%
pd.DataFrame(val_predictions).value_counts()
# Out:
# 1    509
# 0    223
# Name: count, dtype: int64

# %%
### plot training 
res = pd.DataFrame(results.values())
res.columns = ['tuple']

res['train_acc'] = res['tuple'].apply(lambda x : x[0])
res['test_acc'] = res['tuple'].apply(lambda x : x[1])

del res['tuple']
res.index = results.keys()


import matplotlib.pyplot as plt
plt.figure(figsize=(10,7))
plt.plot(res.index, res['train_acc'], color = 'b')
plt.plot(res.index, res['test_acc'], color = 'green')
plt.title('Train vs Test Accucacy per Epoch')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 ### plot training
# ----> 2 res = pd.DataFrame(results.values())
#       3 res.columns = ['tuple']
#       5 res['train_acc'] = res['tuple'].apply(lambda x : x[0])
#
# NameError: name 'pd' is not defined

# %%
res.test_acc.max()
# Out:
# 0.5519125683060109
