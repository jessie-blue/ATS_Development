# %%
import PyPDF2

# Path to the PDF file
pdf_path = 'AAPLE.pdf'

text = ""

# Open the PDF file
with open(pdf_path, 'rb') as file:
    # Create a PDF reader object
    pdf_reader = PyPDF2.PdfFileReader(file)
    
    # Get the number of pages
    num_pages = pdf_reader.getNumPages()
    print(f'The PDF file has {num_pages} pages.')
    
    # Extract text from each page
    for page_num in range(num_pages):
        page = pdf_reader.getPage(page_num)
        page_text = page.extract_text()
        print(f'--- Page {page_num + 1} ---')
        print(page_text)
        
        text += page_text
# Out:
# The PDF file has 28 pages.
# --- Page 1 ---
# UNITED STATES
# SECURITIES AND EXCHANGE COMMISSION
# Washington, D.C. 20549
# FORM 10-Q
# (Mark One)
#  QUARTERL Y REPORT PURSUANT T O SECTION 13 OR 15(d) OF THE SECURITIES EXCHANGE ACT OF 1934
# For the quarterly period ended March 30, 2024
# or
#  TRANSITION REPORT PURSUANT T O SECTION 13 OR 15(d) OF THE SECURITIES EXCHANGE ACT OF 1934
# For the transition period from              to             .
# Commission File Number: 001-36743
# Apple Inc.
# (Exact name of Registrant as specified in its charter)
# California 94-24041 10
# (State or other jurisdiction
# of incorporation or organization)(I.R.S. Employer Identification No.)
# One Apple Park W ay
# Cupertino, California 95014
# (Address of principal executive offices) (Zip Code)
# (408) 996-1010
# (Registrant’s telephone number, including area code)
# Securities registered pursuant to Section 12(b) of the Act:
# ...

# %%
import PyPDF2

# Function to extract text from a PDF file
def extract_text_from_pdf(pdf_path):
    pdf_reader = PyPDF2.PdfFileReader(open(pdf_path, 'rb'))
    text = ""
    for page_num in range(pdf_reader.numPages):
        page = pdf_reader.getPage(page_num)
        text += page.extract_text()
    return text

# Example usage
pdf_path = 'TESLA.pdf'  # Replace with the path to your PDF file
pdf_text = extract_text_from_pdf(pdf_path)
print(pdf_text)
# Out:
# Tesla shares headed for their steepest slump since January after the electric vehicle maker reported
# weaker-than-expected quarterly earnings and another drop in automotive revenue.
# The stock fell 11% as of late Wednesday morning to $219.58. It’s now down 12% for the year,
# while the Nasdaq is up 17% over that stretch.
# Tesla on Tuesday said auto revenue declined 7% from a year earlier to $19.9 billion  while margins
# also fell. Total revenue increased 2% to $25.5 billion.
# The company has been forced to slash prices globally and offer discounts and incentives as it faces
# slowing sales and rising competition, especially in China.
# Tesla remains the top seller of electric vehicles in the U.S. by far, but is losing market share to a
# growing number of rivals due in part to its aging lineup of sedans and SUVs and the impact of
# Musk’s incendiary and political commentary.
# Adjusted earnings of 52 cents a share for the second quarter trailed the average analyst estimate of
# ...

# %%
from textblob import TextBlob

# Function to perform sentiment analysis
def analyze_sentiment(text):
    blob = TextBlob(text)
    return blob.sentiment

# Example usage
sentiment = analyze_sentiment(pdf_text)
print(sentiment)
# Out:
# Sentiment(polarity=0.012894092439546985, subjectivity=0.38503979185797366)

# %%
openai_api = "sk-proj-Eeeq3ay5PswW9xwrV6JrT3BlbkFJXMUTOQZwdg1sKjwLyAHD"

# %%
import PyPDF2
import openai

# Function to extract text from a PDF file
def extract_text_from_pdf(pdf_path):
    pdf_reader = PyPDF2.PdfFileReader(open(pdf_path, 'rb'))
    text = ""
    for page_num in range(pdf_reader.numPages):
        page = pdf_reader.getPage(page_num)
        text += page.extract_text()
    return text

# Function to perform sentiment analysis using OpenAI's API
def analyze_sentiment_with_chatgpt(text, api_key):
    openai.api_key = api_key

    response = openai.ChatCompletion.create(
        model="gpt-4",
        messages=[
            {"role": "system", "content": "You are a helpful assistant that performs sentiment analysis."},
            {"role": "user", "content": f"Please analyze the sentiment of the following text: {text}"}
        ]
    )

    sentiment = response.choices[0].message['content'].strip()
    return sentiment

# Example usage
pdf_path = 'TESLA.pdf'  # Replace with the path to your PDF file
pdf_text = extract_text_from_pdf(pdf_path)
api_key = "sk-proj-Eeeq3ay5PswW9xwrV6JrT3BlbkFJXMUTOQZwdg1sKjwLyAHD"  # Replace with your OpenAI API key
sentiment = analyze_sentiment_with_chatgpt(pdf_text, api_key)
print(sentiment)
# Out:
# ---------------------------------------------------------------------------
# APIRemovedInV1                            Traceback (most recent call last)
# Cell In[18], line 32
#      30 pdf_text = extract_text_from_pdf(pdf_path)
#      31 api_key = "sk-proj-Eeeq3ay5PswW9xwrV6JrT3BlbkFJXMUTOQZwdg1sKjwLyAHD"  # Replace with your OpenAI API key
# ---> 32 sentiment = analyze_sentiment_with_chatgpt(pdf_text, api_key)
#      33 print(sentiment)
#
# Cell In[18], line 17, in analyze_sentiment_with_chatgpt(text, api_key)
#      14 def analyze_sentiment_with_chatgpt(text, api_key):
#      15     openai.api_key = api_key
# ---> 17     response = openai.ChatCompletion.create(
#      18         model="gpt-4",
#      19         messages=[
#      20             {"role": "system", "content": "You are a helpful assistant that performs sentiment analysis."},
#      21             {"role": "user", "content": f"Please analyze the sentiment of the following text: {text}"}
#      22         ]
# ...

# %%
import openai

# Set your OpenAI API key
openai.api_key = "sk-proj-Eeeq3ay5PswW9xwrV6JrT3BlbkFJXMUTOQZwdg1sKjwLyAHD"

# Define a function to call the API
def get_chatgpt_response(prompt):
    response = openai.Completion.create(
        engine="text-davinci-003",  # You can change the engine as needed
        prompt=prompt,
        max_tokens=150,             # Adjust the number of tokens as needed
        n=1,
        stop=None,
        temperature=0.7
    )
    return response.choices[0].text.strip()

# Example input data
input_data = "Tell me a joke about programmers."

# Get response from ChatGPT
response_text = get_chatgpt_response(input_data)

# Print the response
print("ChatGPT response:", response_text)
# Out:
# ---------------------------------------------------------------------------
# APIRemovedInV1                            Traceback (most recent call last)
# Cell In[19], line 22
#      19 input_data = "Tell me a joke about programmers."
#      21 # Get response from ChatGPT
# ---> 22 response_text = get_chatgpt_response(input_data)
#      24 # Print the response
#      25 print("ChatGPT response:", response_text)
#
# Cell In[19], line 8, in get_chatgpt_response(prompt)
#       7 def get_chatgpt_response(prompt):
# ----> 8     response = openai.Completion.create(
#       9         engine="text-davinci-003",  # You can change the engine as needed
#      10         prompt=prompt,
#      11         max_tokens=150,             # Adjust the number of tokens as needed
#      12         n=1,
#      13         stop=None,
#      14         temperature=0.7
#      15     )
#      16     return response.choices[0].text.strip()
#
# ...

# %%
import openai

# Set your OpenAI API key
openai.api_key = "sk-proj-Eeeq3ay5PswW9xwrV6JrT3BlbkFJXMUTOQZwdg1sKjwLyAHD"
openai.api_key = "sk-proj-i0DHprLVXjRDpkqQfO0oT3BlbkFJOLRL4ZQwHAu0CwEWmtTH"

# Define a function to call the API
def get_chatgpt_response(prompt):
    response = openai.ChatCompletion.create(
        model="gpt-3.5-turbo",  # You can use "gpt-3.5-turbo" or "gpt-4" or another model
        messages=[
            {"role": "user", "content": prompt}
        ],
        max_tokens=150,         # Adjust the number of tokens as needed
        temperature=0.7
    )
    return response.choices[0].message['content'].strip()

# Example input data
input_data = "Tell me a joke about programmers."

# Get response from ChatGPT
response_text = get_chatgpt_response(input_data)

# Print the response
print("ChatGPT response:", response_text)
# Out:
# ---------------------------------------------------------------------------
# APIRemovedInV1                            Traceback (most recent call last)
# Cell In[37], line 23
#      20 input_data = "Tell me a joke about programmers."
#      22 # Get response from ChatGPT
# ---> 23 response_text = get_chatgpt_response(input_data)
#      25 # Print the response
#      26 print("ChatGPT response:", response_text)
#
# Cell In[37], line 9, in get_chatgpt_response(prompt)
#       8 def get_chatgpt_response(prompt):
# ----> 9     response = openai.ChatCompletion.create(
#      10         model="gpt-3.5-turbo",  # You can use "gpt-3.5-turbo" or "gpt-4" or another model
#      11         messages=[
#      12             {"role": "user", "content": prompt}
#      13         ],
#      14         max_tokens=150,         # Adjust the number of tokens as needed
#      15         temperature=0.7
#      16     )
#      17     return response.choices[0].message['content'].strip()
#
# ...

# %%
import os
from openai import OpenAI

api_key = "sk-proj-Eeeq3ay5PswW9xwrV6JrT3BlbkFJXMUTOQZwdg1sKjwLyAHD"

client = OpenAI(
    # This is the default and can be omitted
    api_key=api_key,
)

chat_completion = client.chat.completions.create(
    messages=[
        {
            "role": "user",
            "content": "Say this is a test",
        }
    ],
    model="gpt-3.5-turbo",
)
# Out:
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# Cell In[35], line 11
#       4 api_key = "sk-proj-Eeeq3ay5PswW9xwrV6JrT3BlbkFJXMUTOQZwdg1sKjwLyAHD"
#       6 client = OpenAI(
#       7     # This is the default and can be omitted
#       8     api_key=api_key,
#       9 )
# ---> 11 chat_completion = client.chat.completions.create(
#      12     messages=[
#      13         {
#      14             "role": "user",
#      15             "content": "Say this is a test",
#      16         }
#      17     ],
#      18     model="gpt-3.5-turbo",
#      19 )
#
# File c:\Users\User\.conda\envs\pytorch\Lib\site-packages\openai\_utils\_utils.py:277, in wrapper(*args, **kwargs)
#
# ...

# %%
from openai import OpenAI
client = OpenAI(api_key=api_key)

response = client.chat.completions.create(
  model="gpt-3.5-turbo",
  messages=[
    {"role": "user", "content": "Who won the world series in 2020?"},
  ]
)
# Out:
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# Cell In[36], line 4
#       1 from openai import OpenAI
#       2 client = OpenAI(api_key=api_key)
# ----> 4 response = client.chat.completions.create(
#       5   model="gpt-3.5-turbo",
#       6   messages=[
#       7     {"role": "user", "content": "Who won the world series in 2020?"},
#       8   ]
#       9 )
#
# File c:\Users\User\.conda\envs\pytorch\Lib\site-packages\openai\_utils\_utils.py:277, in wrapper(*args, **kwargs)
#
# File c:\Users\User\.conda\envs\pytorch\Lib\site-packages\openai\resources\chat\completions.py:579, in create(self, messages, model, frequency_penalty, function_call, functions, logit_bias, logprobs, max_tokens, n, presence_penalty, response_format, seed, stop, stream, temperature, tool_choice, tools, top_logprobs, top_p, user, extra_headers, extra_query, extra_body, timeout)
#
# ...

# %%
import openai 

openai.api_key = 'sk-proj-Eeeq3ay5PswW9xwrV6JrT3BlbkFJXMUTOQZwdg1sKjwLyAHD'


def poem_on_samosa():
    prompt = 'write a short poem'
    

    response = openai.ChatCompletion.create(
        
        model = "gpt-3.5-turbo",
        messages = [
            {"role" : "user", "content" : "write a short poem"}
        ]
        
    )
    print(response.choices[0]['message']['content'])
    
poem_on_samosa()
# Out:
# ---------------------------------------------------------------------------
# APIRemovedInV1                            Traceback (most recent call last)
# Cell In[39], line 20
#      10     response = openai.ChatCompletion.create(
#      11
#      12         model = "gpt-3.5-turbo",
#    (...)
#      16
#      17     )
#      18     print(response.choices[0]['message']['content'])
# ---> 20 poem_on_samosa()
#
# Cell In[39], line 10, in poem_on_samosa()
#       6 def poem_on_samosa():
#       7     prompt = 'write a short poem'
# ---> 10     response = openai.ChatCompletion.create(
#      11
#      12         model = "gpt-3.5-turbo",
#      13         messages = [
#      14             {"role" : "user", "content" : "write a short poem"}
#      15         ]
#      16
#      17     )
#      18     print(response.choices[0]['message']['content'])
#
# ...
